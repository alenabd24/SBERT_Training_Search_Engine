# %% [markdown]
# <a href="https://colab.research.google.com/github/alenabd24/SBERT_Training_Search_Engine/blob/main/SBERT_TRAINING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **SBERT Training**

# %% [markdown]
# ## Collection
#
# **What It Is:**
# A large file that contains all the text in the dataset—specifically, each passage (or document). For Passage Ranking, it typically consists of rows formatted as:
# `pid<TAB>passage_text`
# linking a passage ID (`pid`) to its actual text.
#
# **Usage:**
# I use the collection file to look up the actual text for each passage by its ID.
#
# ---
#
# ## Queries
#
# **What It Is:**
# A list of user queries that are either real or anonymized.
#
# **Typical Format:**
# The file is usually formatted as:
# `qid<TAB>query_text`
# mapping each query ID (`qid`) to its corresponding query.
#
# **Usage:**
# I retrieve passages for these queries during the training and evaluation phases of my model.
#
# ---
#
# ## Qrels.train
#
# **What It Is:**
# The relevance judgments (qrels) for the training queries. This file uses the TREC format, such as:
# `qid 0 pid relevance_label`
#
# **Usage:**
# It tells me which (`qid`, `pid`) pairs are actually relevant. For pointwise training, I treat these pairs as positive examples (`label=1`) and assume that any other (`qid`, `pid`) pair in my candidate set is negative (`label=0`).
#
# ---
#
# ## Qrels.dev
#
# **What It Is:**
# The relevance judgments for the development (or validation) queries.
#
# **Usage:**
# I use the dev set to evaluate how well my model generalizes to unseen data. For each dev query, I can identify which passages are relevant (`label=1`) and compute metrics like MRR or nDCG.
#
# ---
#
# ## Putting It All Together
#
# 1. **Load passages**
#    Load the passages from the collection file into a dictionary (mapping `pid` → `passage_text`).
#
# 2. **Load queries**
#    Load the queries into another dictionary (mapping `qid` → `query_text`).
#
# 3. **Form training samples**
#    Use the `qrels.train` file to form `(query, passage, label)` training samples for my model, where the label is set to `1` if the (`qid`, `pid`) pair is marked relevant in `qrels.train`, and `0` otherwise.
#
# 4. **Evaluate on dev set**
#    After training, evaluate the performance of my model using the separate `qrels.dev` file, which provides a held-out set of queries and their corresponding relevant passages.
#
# This pipeline allows me to train my model on a well-defined set of relevance judgments and then assess its effectiveness on unseen data, ensuring that my re-ranker generalizes well before final testing.

# %% [markdown]
# #**Step-by-Step Approach in this Notebook:**
# 1. Prepare Training Data
# 2. Load a pre-trained SBERT model
# 3. Convert data for SBERT training
# 4. Train SBERT
# 5. Evaluate model
# 6. Save the fine-tuned model ready to be used post FAISS

# %%
pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.32.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 127.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 66.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 99.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install ftfy
# Out:
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "qrels.train.tsv"
file_path = '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/qrels.train.tsv'

df_qrels = pd.read_csv(
    file_path,
    sep='\t',           # tab-separated
    header=None,
    names=["qid", "unused", "pid", "rel"]  # column names for clarity
)

df_qrels.head()
# Out:
#        qid  unused  pid  rel
# 0  1185869       0    0    1
# 1  1185868       0   16    1
# 2   597651       0   49    1
# 3   403613       0   60    1
# 4  1183785       0  389    1

# %%
df_qrels.shape
# Out:
# (532761, 4)

# %% [markdown]
# 4 columns, 532,761 rows

# %% [markdown]
# * qid is query id
# * pid is passage id
# * rel is relevance label

# %%
import pandas as pd

#file_path = "queries.train.tsv"
file_path = '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/queries.train.tsv'

df_queries = pd.read_csv(
    file_path,
    sep='\t',
    header=None,
    names=["qid", "query_text"]
)

df_queries.head()
# Out:
#       qid                                query_text
# 0  121352                            define extreme
# 1  634306  what does chattel mean on credit history
# 2  920825   what was the great leap forward brainly
# 3  510633       tattoo fixers how much does it cost
# 4  737889         what is decentralization process.

# %%
df_queries.shape
# Out:
# (808731, 2)

# %%
df_collection = pd.read_csv(
    '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/collection.tsv',
    sep='\t',
    header=None,
    names=['pid', 'passage']
)
df_collection.head()
# Out:
#    pid                                            passage
# 0    0  The presence of communication amid scientific ...
# 1    1  The Manhattan Project and its atomic bomb help...
# 2    2  Essay on The Manhattan Project - The Manhattan...
# 3    3  The Manhattan Project was the name for a proje...
# 4    4  versions of each volume as well as complementa...

# %%
df_collection.shape
# Out:
# (8841823, 2)

# %%
df_collection.loc[49, "passage"]
# Out:
# 'Colorâ\x80\x94urine can be a variety of colors, most often shades of yellow, from very pale or colorless to very dark or amber. Unusual or abnormal urine colors can be the result of a disease process, several medications (e.g., multivitamins can turn urine bright yellow), or the result of eating certain foods.'

# %% [markdown]
# ^As you can see there is a problem with formatting in some entries in the data. I need to clean it

# %%
from ftfy import fix_text

# Fix encoding in 'passage'
df_collection["passage"] = df_collection["passage"].apply(fix_text)

# Check result
print(df_collection.loc[49, "passage"])

# %%
print(df_collection.loc[49, "passage"])

# %% [markdown]
# Above you can see that the passages were fixed. Let's now do same for query text.

# %%
from ftfy import fix_text

# Fix encoding in 'query text'
df_queries["query_text"] = df_queries["query_text"].apply(fix_text)

# %%
df_queries.head()

# %%
print(df_queries.loc[121352, "query_text"])

# %% [markdown]
# ##**Now we can merge all tables into a dataframe:**

# %%
# Merge qrels with queries on 'qid'
df_merged = pd.merge(df_qrels, df_queries, on='qid', how='left')

# Merge the resulting positives with the collection on 'pid'
df_merged = pd.merge(df_merged, df_collection, on='pid', how='left')

df_merged.drop(["unused"], axis=1, inplace=True)

df_merged.head()

# %%
df_merged.shape

# %% [markdown]
# saving this merged df:

# %%
df_merged.to_csv('df_merged.csv', index=False)
from google.colab import files
files.download('df_merged.csv')

# %%
df_merged = pd.read_csv('df_merged.csv')

# %% [markdown]
# Now I don't need to run all the code before this cell, i can just import df_merged.csv

# %% [markdown]
# You can see that the dataframe has 532,761 rows (data points)

# %% [markdown]
# **The dataframe above cannot yet be used for training the model, as it contains queries, passages and positive relevance scores. I need to add negative relevance scores**

# %%
pip install joblib

# %%
# all_pids is the list of all passage IDs from the collection
all_pids = df_collection['pid'].unique().tolist()

# %%
df_merged.head()

# %%
df_merged['rel'].unique()

# %% [markdown]
# Checking how many CPU cores i have

# %%
import multiprocessing

num_cores = multiprocessing.cpu_count()
print("Number of CPU cores:", num_cores)

# %% [markdown]
# **Negative Sampling:**
#
# MS Marco Dataset only contains query-passage pairs with positive relevancy, so negative (0) relevancy pairs have to be manually generated. Here's the plan:
#
# Progressive approach:
# * Start with generating 50,000 negative pairs (by increasing queries to ~5,000 and negatives per query to 10)
# * Then subsample the positives to 50,000
# * This gives you a balanced dataset of 100,000 examples, which is sufficient for initial

# %%
import random
import pandas as pd

# Ensure keys are of the same type across DataFrames and all_pids
# convert key columns to str for consistency
df_qrels['qid'] = df_qrels['qid'].astype(str)
df_qrels['pid'] = df_qrels['pid'].astype(str)
df_queries['qid'] = df_queries['qid'].astype(str)
df_collection['pid'] = df_collection['pid'].astype(str)

# Ensure all_pids are strings as well
all_pids = [str(pid) for pid in all_pids]

# Debug: Print data types to verify consistency
print("df_qrels dtypes:")
print(df_qrels.dtypes)
print("\ndf_queries dtypes:")
print(df_queries.dtypes)
print("\ndf_collection dtypes:")
print(df_collection.dtypes)
print("\nType of first element in all_pids:", type(all_pids[0]))


# Sample 5000 QUERIES to generate 50k negatives

all_qids = df_qrels["qid"].unique().tolist()
random.shuffle(all_qids)

subsample_size = 5000  # Target ~5000 queries
sub_qids = all_qids[:subsample_size]
print(f"Selected {len(sub_qids)} unique queries for negative sampling")

# Process in reasonable chunks

chunk_size = 100
chunks = [sub_qids[i : i + chunk_size] for i in range(0, len(sub_qids), chunk_size)]
print(f"Split into {len(chunks)} chunks of {chunk_size} queries each")

# Build a dictionary of positives for each qid
pos_dict = {}
for row in df_qrels.itertuples(index=False):
    q = row.qid
    p = row.pid
    if q not in pos_dict:
        pos_dict[q] = set()
    pos_dict[q].add(p)


# Improved negative sampling function

def sample_negatives_for_qid(qid, max_samples=10):
    """
    For a given qid, efficiently sample negative passages.

    Args:
        qid: The query ID
        max_samples: Maximum number of negative samples to generate

    Returns:
        List of (qid, pid, 0) tuples representing negative samples
    """
    pos_pids = pos_dict.get(qid, set())

    # Fixed number of negatives per query to prevent excessive sampling
    neg_samples = []
    attempts = 0
    max_attempts = max_samples * 20  # Allow more failed attempts

    while len(neg_samples) < max_samples and attempts < max_attempts:
        attempts += 1
        # Pick a random pid from all_pids
        pid = random.choice(all_pids)
        # Only add if it's not a positive for this query
        if pid not in pos_pids and (qid, pid, 0) not in neg_samples:
            neg_samples.append((qid, pid, 0))

    return neg_samples


# Process each chunk sequentially with progress tracking
all_neg_samples = []  # store negative samples
target_negatives = 50000
negatives_per_query = min(10, target_negatives // len(sub_qids) + 1)

print(f"Target: {target_negatives} negatives at {negatives_per_query} per query")

for idx, chunk_qids in enumerate(chunks):
    print(f"Processing chunk {idx+1}/{len(chunks)}: {len(chunk_qids)} queries")

    # Process queries sequentially
    for i, qid in enumerate(chunk_qids):
        neg_samples = sample_negatives_for_qid(qid, max_samples=negatives_per_query)
        all_neg_samples.extend(neg_samples)

        # Progress update every 50 queries
        if (i+1) % 50 == 0 or i+1 == len(chunk_qids):
            print(f"  -> Processed {i+1}/{len(chunk_qids)} queries in current chunk")
            print(f"  -> Total negatives so far: {len(all_neg_samples)}")

    # Check if we've reached our target
    if len(all_neg_samples) >= target_negatives:
        print(f"Reached target of {target_negatives} negatives. Stopping.")
        break

#Convert negative pairs to DataFrame

df_neg = pd.DataFrame(all_neg_samples[:target_negatives], columns=["qid", "pid", "rel"])
print("\nTotal negative pairs:", len(df_neg))
print("Sample of negative pairs:")
print(df_neg.head())


# Merge negative pairs with query and passage text

print("Merging negative pairs with query and passage text...")
df_neg_merged = pd.merge(df_neg, df_queries, on='qid', how='left')
df_neg_merged = pd.merge(df_neg_merged, df_collection, on='pid', how='left')


# Subsample positives to match number of negatives
print(f"Subsampling {len(df_neg)} positives from {len(df_merged)} total positives...")
df_pos_subsampled = df_merged.sample(n=len(df_neg), random_state=42)


# Create final balanced dataset

df_balanced = pd.concat([df_pos_subsampled, df_neg_merged], ignore_index=True)
df_balanced = df_balanced.sample(frac=1.0, random_state=42)  # Shuffle the dataset

print("\nFinal balanced dataset size:", df_balanced.shape[0])
print("Class distribution:")
print(df_balanced["rel"].value_counts())
print("\nSample of the balanced dataset:")
print(df_balanced.head(5))

# Save the balanced dataset
df_balanced.to_csv('balanced_dataset_100k.csv', index=False)
print("Balanced dataset saved to 'balanced_dataset_100k.csv'")

# %%
df_balanced

# %%
df_negative_pairs = df_balanced[df_balanced['rel'] == 0]
df_positive_pairs = df_balanced[df_balanced['rel'] == 1]

# %%
df_negative_pairs

# %%
df_positive_pairs

# %% [markdown]
# You can see both of the classes have 50,000 pairs. This dataframe can be used to train our model.

# %%
from google.colab import files

#Save df_all to a CSV file in the Colab environment
df_balanced.to_csv('df_balanced.csv', index=False)

#Download the CSV file to your local machine
files.download('df_balanced.csv')

# %%
file_path = '/content/df_merged.cs'
with open(file_path, 'r') as file:
    data = file.read()
print(data)

# %%
file_path = '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/df_balanced.csv'

df_balanced = pd.read_csv(file_path)

df_balanced.head(5)

# %%
print(df_balanced['rel'].value_counts())

# %% [markdown]
# confirming class balance

# %% [markdown]
# # Choosing and importing a relevant SBERT Model:

# %% [markdown]
# When a query comes in, SBERT classifier (pre-trained on MS MARCO) generates an embedding for the query and each of the 10 candidate academic passages. It then computes cosine similarities between the query and each candidate. The final ranking is produced by ordering the candidates from highest to lowest similarity. In other words, the classifier scores the candidates based on their semantic relevance to the query, and these scores are used to produce a ranking.

# %%
# !pip install evaluate

# %%
# !pip install datasets
# !pip install transformers
# !pip install accelerate -U
# !pip install transformers[torch]
# !pip install wandb

# %%
from sentence_transformers import SentenceTransformer, InputExample, losses, evaluation
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import multiprocessing
from datasets import Dataset
from transformers import AutoTokenizer

import evaluate
import torch

# %%
from sentence_transformers import InputExample
from torch.utils.data import DataLoader
import random

# 1. Split the balanced dataset into train and validation sets
train_df, val_df = train_test_split(
    df_balanced,
    test_size=0.1,
    random_state=42,
    stratify=df_balanced['rel']  # Maintain class balance in splits
)

print(f"Training samples: {len(train_df)}")
print(f"Validation samples: {len(val_df)}")

# 2. Convert DataFrames to lists of InputExample objects
def df_to_input_examples(df):
    examples = []
    for _, row in df.iterrows():
        # SBERT expects InputExample objects with texts and a label
        examples.append(InputExample(
            texts=[row['query_text'], row['passage']],
            label=float(row['rel'])
        ))
    return examples

train_examples = df_to_input_examples(train_df)
val_examples = df_to_input_examples(val_df)

# Sample some examples to verify
print("\nSample training examples:")
for i in range(3):
    ex = random.choice(train_examples)
    print(f"Query: {ex.texts[0][:50]}...")
    print(f"Passage: {ex.texts[1][:50]}...")
    print(f"Label: {ex.label}\n")

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = SentenceTransformer('sentence-transformers/msmarco-distilbert-base-v4')
model = model.to(device)  # Automatically uses GPU if available

train_dataloader = DataLoader(train_examples, shuffle=True, batch_size=32)

# Define loss
train_loss = losses.CosineSimilarityLoss(model=model)

# Create evaluator for validation set
evaluator = EmbeddingSimilarityEvaluator.from_input_examples(val_examples, name='val-eval')

# Fine-tune the model
model.fit(
    train_objectives=[(train_dataloader, train_loss)],
    evaluator=evaluator,
    epochs=2,
    evaluation_steps=100,  # Validation every 100 steps
    output_path='/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/SBERT_MODEL/'
)

# %%
# this snipped loads a previouysly saved model from a directory to this notebook environment
# from sentence_transformers import SentenceTransformer

# # Path where you saved the model
# model_path = '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/SBERT_MODEL_13TH_APRIL/'

# # Load the model
# model = SentenceTransformer(model_path)

# %% [markdown]
# Preparing the test set:

# %% [markdown]
# **Training and monitoring evaluation:**

# %% [markdown]
# **Post-Training Validation:**
# * Load the official test set - qrels.dev.tsv

# %%
#Read qrels.dev.tsv
test_qrels = pd.read_csv(
    '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/qrels.dev.tsv',
    sep='\t',
    header=None,
    names=['qid', 'unused', 'pid', 'rel']  # "unused" corresponds to the '0' column
)

# read queries.dev.tsv
test_queries = pd.read_csv(
    '/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/queries.dev.tsv',
    sep='\t',
    header=None,
    names=['qid', 'query_text']
)

# %% [markdown]
# For final validation we are using the MS MARCO's dev set, which was not used for training or fine-tuning model parameters. In theory it should serve as an unbiased performance assessment.
#
# **When i run the BinaryClassificationEvaluator, it does the following:**
# 1. Feeds each pair to your model to get a similarity score (e.g., cosine similarity between embeddings).
#
# 2. Compares that predicted score vs. the ground-truth rel label for classification metrics (like accuracy, F1, or AUC).

# %%
# merge qrels.dev with queries.dev on 'qid'
# m [qid, unused, pid, rel, query_text]
test_merged = pd.merge(test_qrels, test_queries, on='qid', how='left')

# Merge again with collection on 'pid' to get the passage text
#    [qid, unused, pid, rel, query_text, passage]
test_merged = pd.merge(test_merged, df_collection, on='pid', how='left')

# (Optional) drop the 'unused' column
test_merged.drop(columns=['unused'], inplace=True)

print("Dev set (test) shape:", test_merged.shape)
test_merged.head()

# %%
print(test_merged['rel'].value_counts())

# %%
import pandas as pd

# Check if test_merged has at least 5000 samples
if test_merged.shape[0] > 5000:
    test_merged_sub = test_merged.sample(n=5000, random_state=42).reset_index(drop=True)
    print("Subsampled test_merged to 5,000 data samples.")
else:
    test_merged_sub = test_merged.copy()
    print("test_merged has less than 5,000 samples; no subsampling performed.")

# Optional: Print the shape and a preview of the subsampled DataFrame
print("New shape of test_merged_sub:", test_merged_sub.shape)
print(test_merged_sub.head())

# %% [markdown]
# Above we can see that the test dataset only has positive relevancy query-passage pairs, so once again we have to manually generate negative relevancy pairs.
#
# We don't need to validate our model with 120k data samples - that's overkill. I'm gonna sample test_merged to 5000 rows, and generate 5k more negative pairs.

# %% [markdown]
# Confirming we cut the dataset to 5k entries:

# %%
print(test_merged_sub['rel'].value_counts())

# %% [markdown]
# Generating 5k negative query-passage pairs

# %%
import random
import pandas as pd

#  Ensure keys are strings for consistency
test_merged_sub['qid'] = test_merged_sub['qid'].astype(str)
test_merged_sub['pid'] = test_merged_sub['pid'].astype(str)
test_queries['qid'] = test_queries['qid'].astype(str)
df_collection['pid'] = df_collection['pid'].astype(str)

# Get all passage IDs from the collection
all_pids = list(df_collection['pid'].unique())

#  Build a dictionary of positives from test_merged_sub
test_pos_dict = {}
for _, row in test_merged_sub.iterrows():
    qid = row['qid']
    pid = row['pid']
    if qid not in test_pos_dict:
        test_pos_dict[qid] = set()
    test_pos_dict[qid].add(pid)

# Negative sampling function (1:1 ratio with positives)

def sample_negatives_for_qid_test(qid, max_samples):
    """
    For a given test query id, sample negative passages (ones not in the positive set).
    max_samples is set to match the number of positives for that query.
    """
    pos_pids = test_pos_dict.get(qid, set())
    neg_samples = []
    attempts = 0
    max_attempts = max_samples * 20  # Allow extra attempts if needed
    while len(neg_samples) < max_samples and attempts < max_attempts:
        attempts += 1
        pid = random.choice(all_pids)
        if pid not in pos_pids and (qid, pid, 0) not in neg_samples:
            neg_samples.append((qid, pid, 0))
    return neg_samples

# Process queries in chunks to generate negative samples
# Create a shuffled list of qids from the subsampled test data
all_qids = list(test_pos_dict.keys())
random.shuffle(all_qids)

# Define chunk size (here we use 100 queries per chunk)
chunk_size = 100
chunks = [all_qids[i:i + chunk_size] for i in range(0, len(all_qids), chunk_size)]
print(f"Total queries to process: {len(all_qids)} in {len(chunks)} chunks of {chunk_size} each.")

neg_samples_list = []

# Process each chunk sequentially
for idx, chunk_qids in enumerate(chunks):
    print(f"Processing chunk {idx+1}/{len(chunks)} with {len(chunk_qids)} queries.")
    for qid in chunk_qids:
        # retrieve the query text from test_queries
        query_rows = test_queries[test_queries['qid'] == qid]
        if query_rows.empty:
            continue
        query_text = query_rows.iloc[0]['query_text']

        # Set negatives count equal to number of positives for this query
        num_pos = len(test_pos_dict[qid])
        neg_samples = sample_negatives_for_qid_test(qid, num_pos)

        # For each negative, lookup its passage text from df_collection
        for (qid_neg, pid_neg, rel_neg) in neg_samples:
            passage_rows = df_collection[df_collection['pid'] == pid_neg]
            if passage_rows.empty:
                continue
            passage_text = passage_rows.iloc[0]['passage']
            neg_samples_list.append({
                'qid': qid_neg,
                'pid': pid_neg,
                'rel': rel_neg,
                'query_text': query_text,
                'passage': passage_text
            })

    print(f"  -> Total negatives so far: {len(neg_samples_list)}")

print("Finished processing all chunks.")

# convert negative samples into a DataFrame
df_neg_test = pd.DataFrame(neg_samples_list)
print("Total negative samples for evaluation:", len(df_neg_test))
print("Negative samples preview:")
print(df_neg_test.head())


# Combine with positive pairs (from the subsampled test set) to create final evaluation DataFrame

df_pos_test = test_merged_sub[['qid', 'pid', 'rel', 'query_text', 'passage']]
test_final = pd.concat([df_pos_test, df_neg_test], ignore_index=True)
test_final = test_final.sample(frac=1.0, random_state=42).reset_index(drop=True)

# Check class distribution
print("Final evaluation set class distribution:")
print(test_final['rel'].value_counts())
print("\nFinal evaluation set preview:")
print(test_final.head())

# %% [markdown]
# Saving test_final as a csv locally:

# %%
from google.colab import files

# Save test_final to a CSV file (without the index column)
test_final.to_csv('test_final.csv', index=False)

# Trigger a download of the CSV file
files.download('test_final.csv')

# %% [markdown]
# ## **Evaluation:**

# %% [markdown]
# The code is evaluating your model’s ability to decide whether a pair of texts (a query and a passage) is relevant (label 1.0) or irrelevant (label 0.0)

# %%
from sentence_transformers import InputExample
from sentence_transformers.evaluation import BinaryClassificationEvaluator

# Convert merged test set to InputExamples
test_examples = []
for _, row in test_final.iterrows():
    test_examples.append(InputExample(
        texts=[row['query_text'], row['passage']],
        label=float(row['rel'])  # 1.0 = relevant, 0.0 = irrelevant
    ))

# %%
# Initialise evaluator
evaluator = BinaryClassificationEvaluator.from_input_examples(
    test_examples,
    name='test-eval'
)

# Run evaluation
evaluator(model)
# Out:
# {'test-eval_cosine_accuracy': 0.9865,
#  'test-eval_cosine_accuracy_threshold': 0.5036637783050537,
#  'test-eval_cosine_f1': 0.9865013498650135,
#  'test-eval_cosine_f1_threshold': 0.47773101925849915,
#  'test-eval_cosine_precision': 0.9864027194561088,
#  'test-eval_cosine_recall': 0.9866,
#  'test-eval_cosine_ap': 0.9990008667480205,
#  'test-eval_cosine_mcc': 0.9730000194600006}

# %% [markdown]
# This process ultimately lets you assess how well your fine-tuned SBERT model differentiates between semantically relevant and non-relevant query–passage pairs, which is critical for ranking task

# %% [markdown]
# Ranking:

# %%
import numpy as np
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('/content/drive/MyDrive/Colab_Notebooks/Information Retrieval/Search Engine Project/SBERT_MODEL/')

def compute_cosine_similarity(vec1, vec2):
    """Compute the cosine similarity between two vectors."""
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# Dictionary to store ranking results by query
ranking_results = {}

# Group the evaluation DataFrame by query id
for qid, group in test_final.groupby('qid'):
    # extract query text
    query_text = group.iloc[0]['query_text']
    # Get list of candidate passages and corresponding ids and ground truth labels
    candidate_passages = group['passage'].tolist()
    candidate_ids = group['pid'].tolist()
    candidate_labels = group['rel'].tolist()

    # Compute embeddings
    # For the query:
    query_embedding = model.encode([query_text])[0]  # single embedding vector
    # For candidates:
    candidate_embeddings = model.encode(candidate_passages)

    # Compute cosine similarity scores for each candidate passage
    similarity_scores = [
        compute_cosine_similarity(query_embedding, candidate_emb)
        for candidate_emb in candidate_embeddings
    ]

    # Convert scores to a NumPy array for sorting
    similarity_scores = np.array(similarity_scores)

    # Sort candidate indices based on similarity scores (descending order)
    sorted_indices = np.argsort(-similarity_scores)

    # Retrieve sorted candidates, their ids, scores, and labels
    sorted_candidate_ids = [candidate_ids[i] for i in sorted_indices]
    sorted_scores = similarity_scores[sorted_indices]
    sorted_candidate_labels = [candidate_labels[i] for i in sorted_indices]

    # Store results in a dictionary for this query
    ranking_results[qid] = {
        'query_text': query_text,
        'sorted_candidate_ids': sorted_candidate_ids,
        'sorted_scores': sorted_scores,
        'sorted_candidate_labels': sorted_candidate_labels
    }

    # Print ranking for this query (for demonstration)
    print(f"Query ID: {qid}")
    print("Ranked Passage IDs:", sorted_candidate_ids)
    print("Similarity Scores:", sorted_scores)
    print("\n")

#Compute Mean Reciprocal Rank (MRR) as a ranking metric
def compute_mrr(sorted_labels):
    """Return reciprocal rank for the first relevant (label==1) candidate."""
    for rank, label in enumerate(sorted_labels, start=1):
        if label == 1:
            return 1.0 / rank
    return 0.0

# Calculate MRR for each query and average them
mrr_list = [compute_mrr(data['sorted_candidate_labels']) for data in ranking_results.values()]
mean_mrr = np.mean(mrr_list)
print("Mean Reciprocal Rank (MRR) across queries:", mean_mrr)
# Out:
# Streaming output truncated to the last 5000 lines.
# Ranked Passage IDs: ['7661942', '7306061']
# Similarity Scores: [0.73657346 0.14602663]
#
#
# Query ID: 758008
# Ranked Passage IDs: ['7561394', '1829092']
# Similarity Scores: [0.6587354  0.05528211]
#
#
# Query ID: 758104
# Ranked Passage IDs: ['5536159', '7436084']
# Similarity Scores: [0.8620485  0.13836473]
#
#
# Query ID: 759243
# Ranked Passage IDs: ['7445414', '6566971']
# Similarity Scores: [0.9398777  0.14405185]
#
#
# Query ID: 759861
# Ranked Passage IDs: ['7556003', '1364694']
# Similarity Scores: [0.9324275  0.03937463]
#
#
# Query ID: 760774
# Ranked Passage IDs: ['7884334', '5752137']
# Similarity Scores: [0.80378866 0.03762812]
#
#
# Query ID: 761194
# Ranked Passage IDs: ['7726869', '3988862']
# Similarity Scores: [0.55772984 0.06785862]
#
#
# Query ID: 76169
# Ranked Passage IDs: ['7339645', '1681780']
# Similarity Scores: [0.6684715  0.00907359]
#
#
# Query ID: 761700
# Ranked Passage IDs: ['7717531', '1202799']
# Similarity Scores: [0.8980647  0.02435574]
#
#
# Query ID: 76199
# Ranked Passage IDs: ['7743922', '1328558']
# Similarity Scores: [0.8070473  0.07969522]
#
#
# Query ID: 762158
# Ranked Passage IDs: ['7876246', '8272433']
# Similarity Scores: [0.84589434 0.02648207]
#
#
# Query ID: 762455
# Ranked Passage IDs: ['7951240', '5979385']
# Similarity Scores: [0.8373113  0.12368531]
#
#
# Query ID: 762468
# Ranked Passage IDs: ['7841202', '2508082']
# Similarity Scores: [0.7526193 0.1415532]
#
#
# Query ID: 762555
# Ranked Passage IDs: ['7777477', '2679593']
# Similarity Scores: [0.8641437  0.08946393]
#
#
# Query ID: 762648
# Ranked Passage IDs: ['4455147', '3478733']
# Similarity Scores: [0.70015454 0.05845485]
#
#
# Query ID: 762656
# Ranked Passage IDs: ['4108766', '5370366']
# Similarity Scores: [ 0.64794874 -0.01797005]
#
#
# Query ID: 762767
# Ranked Passage IDs: ['7818056', '5234578']
# Similarity Scores: [0.62110174 0.15185021]
#
#
# Query ID: 763734
# Ranked Passage IDs: ['7920194', '1924244']
# Similarity Scores: [ 0.6450522  -0.00821875]
#
#
# Query ID: 763814
# Ranked Passage IDs: ['7813240', '1313298']
# Similarity Scores: [0.88877046 0.13938947]
#
#
# Query ID: 764370
# Ranked Passage IDs: ['7901218', '1077968']
# Similarity Scores: [0.8681146  0.02647113]
#
#
# Query ID: 764486
# Ranked Passage IDs: ['7758796', '6321437']
# Similarity Scores: [ 0.894585   -0.01097536]
#
#
# Query ID: 764578
# Ranked Passage IDs: ['7814287', '8068278']
# Similarity Scores: [0.78482383 0.04517912]
#
#
# Query ID: 764691
# Ranked Passage IDs: ['7952109', '4934428']
# Similarity Scores: [0.52312434 0.13543591]
#
#
# Query ID: 765475
# Ranked Passage IDs: ['7902583', '3186100']
# Similarity Scores: [0.88029    0.06916393]
#
#
# Query ID: 765484
# Ranked Passage IDs: ['162274', '2479259']
# Similarity Scores: [0.8164682  0.15940206]
#
#
# Query ID: 765802
# Ranked Passage IDs: ['7894344', '6458432']
# Similarity Scores: [0.5475717  0.03800134]
#
#
# Query ID: 765885
# Ranked Passage IDs: ['7942085', '7767880']
# Similarity Scores: [ 0.79189247 -0.00426751]
#
#
# Query ID: 765999
# Ranked Passage IDs: ['7773595', '6061849']
# Similarity Scores: [0.9128095  0.00950411]
#
#
# Query ID: 766545
# Ranked Passage IDs: ['7729989', '8180731']
# Similarity Scores: [0.8727275  0.10917804]
#
#
# Query ID: 766908
# Ranked Passage IDs: ['7942632', '6449845']
# Similarity Scores: [0.86257225 0.00865536]
#
#
# Query ID: 767045
# Ranked Passage IDs: ['7829073', '959194']
# Similarity Scores: [0.7469448  0.10009628]
#
#
# Query ID: 767489
# Ranked Passage IDs: ['7863106', '2198449']
# Similarity Scores: [0.84172726 0.06559069]
#
#
# Query ID: 767902
# Ranked Passage IDs: ['7740056', '133552']
# Similarity Scores: [0.6289942  0.23524067]
#
#
# Query ID: 767927
# Ranked Passage IDs: ['7817917', '5588583']
# Similarity Scores: [0.45767984 0.08162616]
#
#
# Query ID: 768316
# Ranked Passage IDs: ['7920199', '5066566']
# Similarity Scores: [0.9242888  0.07297989]
#
#
# Query ID: 76859
# Ranked Passage IDs: ['7309228', '4280659']
# Similarity Scores: [0.66446006 0.04774705]
#
#
# Query ID: 768611
# Ranked Passage IDs: ['7738446', '1480079']
# Similarity Scores: [0.62438625 0.02454616]
#
#
# Query ID: 768907
# Ranked Passage IDs: ['1011330', '1174090']
# Similarity Scores: [0.7921877  0.08239239]
#
#
# Query ID: 769041
# Ranked Passage IDs: ['7830689', '4764276']
# Similarity Scores: [ 0.88224185 -0.05179164]
#
#
# Query ID: 769230
# Ranked Passage IDs: ['7760550', '8038695']
# Similarity Scores: [0.7381845  0.06630436]
#
#
# Query ID: 769250
# Ranked Passage IDs: ['7961774', '4018838']
# Similarity Scores: [0.8447039  0.14008301]
#
#
# Query ID: 769637
# Ranked Passage IDs: ['247099', '2621405']
# Similarity Scores: [0.9021253  0.14378278]
#
#
# Query ID: 76980
# Ranked Passage IDs: ['2467214', '8493741']
# Similarity Scores: [0.84718126 0.08398315]
#
#
# Query ID: 770246
# Ranked Passage IDs: ['2544934', '4546998']
# Similarity Scores: [ 0.94414383 -0.02948659]
#
#
# Query ID: 770261
# Ranked Passage IDs: ['7953784', '353880']
# Similarity Scores: [0.8494155  0.21613842]
#
#
# Query ID: 771097
# Ranked Passage IDs: ['7963345', '8188995']
# Similarity Scores: [0.40491834 0.31647256]
#
#
# Query ID: 771314
# Ranked Passage IDs: ['7888626', '682701']
# Similarity Scores: [0.6326683  0.01619336]
#
#
# Query ID: 771899
# Ranked Passage IDs: ['7855366', '8455188']
# Similarity Scores: [0.37647563 0.14999154]
#
#
# Query ID: 771952
# Ranked Passage IDs: ['1666422', '4133893']
# Similarity Scores: [0.54331166 0.2727368 ]
#
#
# Query ID: 772046
# Ranked Passage IDs: ['7932335', '8172951']
# Similarity Scores: [ 0.69949883 -0.02331144]
#
#
# Query ID: 77311
# Ranked Passage IDs: ['7317704', '5610033']
# Similarity Scores: [0.8039842  0.11813597]
#
#
# Query ID: 773404
# Ranked Passage IDs: ['6145668', '8433651']
# Similarity Scores: [0.7123605  0.01181455]
#
#
# Query ID: 773409
# Ranked Passage IDs: ['7903262', '6845018']
# Similarity Scores: [0.847613 0.076343]
#
#
# Query ID: 773998
# Ranked Passage IDs: ['7754394', '4936728']
# Similarity Scores: [0.7023454  0.22073367]
#
#
# Query ID: 773999
# Ranked Passage IDs: ['7887820', '8568586']
# Similarity Scores: [0.80713904 0.0117192 ]
#
#
# Query ID: 774945
# Ranked Passage IDs: ['7772852', '4376989']
# Similarity Scores: [0.65453213 0.02133917]
#
#
# Query ID: 775353
# Ranked Passage IDs: ['7966029', '1498851']
# Similarity Scores: [0.7858709  0.09965687]
#
#
# Query ID: 775934
# Ranked Passage IDs: ['7957994', '4024264']
# Similarity Scores: [0.6175268  0.15256685]
#
#
# Query ID: 776128
# Ranked Passage IDs: ['7799002', '6658653']
# Similarity Scores: [0.77394134 0.1811944 ]
#
#
# Query ID: 777390
# Ranked Passage IDs: ['12549', '5682594']
# Similarity Scores: [0.91555715 0.15994042]
#
#
# Query ID: 777652
# Ranked Passage IDs: ['433871', '4013965']
# Similarity Scores: [0.9255587  0.00240014]
#
#
# Query ID: 777898
# Ranked Passage IDs: ['7842260', '270194']
# Similarity Scores: [0.42322925 0.08772819]
#
#
# Query ID: 77823
# Ranked Passage IDs: ['7579309', '2104391']
# Similarity Scores: [0.84933984 0.00735246]
#
#
# Query ID: 778602
# Ranked Passage IDs: ['7954065', '6777360']
# Similarity Scores: [0.8990239  0.20099673]
#
#
# Query ID: 778890
# Ranked Passage IDs: ['7731903', '3030033']
# Similarity Scores: [0.563674   0.04489255]
#
#
# Query ID: 779255
# Ranked Passage IDs: ['7824082', '2821882']
# Similarity Scores: [ 0.76507133 -0.05579727]
#
#
# Query ID: 779553
# Ranked Passage IDs: ['7754366', '8646994']
# Similarity Scores: [0.71271706 0.03867663]
#
#
# Query ID: 780093
# Ranked Passage IDs: ['7868181', '1516882']
# Similarity Scores: [0.77821517 0.08942913]
#
#
# Query ID: 780332
# Ranked Passage IDs: ['7779767', '385461']
# Similarity Scores: [0.8716982  0.13627686]
#
#
# Query ID: 781277
# Ranked Passage IDs: ['4232033', '5596408']
# Similarity Scores: [0.8605559  0.12636884]
#
#
# Query ID: 781378
# Ranked Passage IDs: ['1569361', '5501969']
# Similarity Scores: [0.90609926 0.01456385]
#
#
# Query ID: 781700
# Ranked Passage IDs: ['7939827', '8326217']
# Similarity Scores: [ 0.7889749  -0.06439071]
#
#
# Query ID: 781873
# Ranked Passage IDs: ['7788126', '5027545']
# Similarity Scores: [ 0.7979245  -0.06415984]
#
#
# Query ID: 782199
# Ranked Passage IDs: ['7823765', '6664320']
# Similarity Scores: [0.53256065 0.1263862 ]
#
#
# Query ID: 782438
# Ranked Passage IDs: ['7720810', '1671507']
# Similarity Scores: [0.80454177 0.24226353]
#
#
# Query ID: 782696
# Ranked Passage IDs: ['7805743', '7583106']
# Similarity Scores: [0.65048355 0.02990188]
#
#
# Query ID: 782770
# Ranked Passage IDs: ['7758745', '7869814']
# Similarity Scores: [0.815428   0.08375531]
#
#
# Query ID: 783353
# Ranked Passage IDs: ['7881754', '6675111']
# Similarity Scores: [0.13796736 0.05425847]
#
#
# Query ID: 783843
# Ranked Passage IDs: ['7939473', '8660904']
# Similarity Scores: [0.7469122  0.07785941]
#
#
# Query ID: 783949
# Ranked Passage IDs: ['7823965', '8367947']
# Similarity Scores: [0.4546671  0.21669447]
#
#
# Query ID: 784842
# Ranked Passage IDs: ['7743539', '8518262']
# Similarity Scores: [0.50172764 0.02413954]
#
#
# Query ID: 785217
# Ranked Passage IDs: ['7903533', '4214584']
# Similarity Scores: [0.8223847  0.19414952]
#
#
# Query ID: 785446
# Ranked Passage IDs: ['3679621', '5444259']
# Similarity Scores: [0.7818448  0.05008672]
#
#
# Query ID: 785572
# Ranked Passage IDs: ['1220809', '5890428']
# Similarity Scores: [0.8069868  0.15003398]
#
#
# Query ID: 786021
# Ranked Passage IDs: ['2511493', '1163515']
# Similarity Scores: [ 0.74850065 -0.0713852 ]
#
#
# Query ID: 786791
# Ranked Passage IDs: ['7814384', '742232']
# Similarity Scores: [0.93112826 0.02584152]
#
#
# Query ID: 78729
# Ranked Passage IDs: ['7298153', '4971050']
# Similarity Scores: [0.849422  0.1227057]
#
#
# Query ID: 787486
# Ranked Passage IDs: ['7477082', '4587635']
# Similarity Scores: [0.8389079 0.3591807]
#
#
# Query ID: 788347
# Ranked Passage IDs: ['7958123', '1915668']
# Similarity Scores: [ 0.832694   -0.01724919]
#
#
# Query ID: 789042
# Ranked Passage IDs: ['7921777', '7217851']
# Similarity Scores: [0.71520406 0.12684625]
#
#
# Query ID: 790178
# Ranked Passage IDs: ['7946325', '6136916']
# Similarity Scores: [0.926228   0.11025124]
#
#
# Query ID: 791184
# Ranked Passage IDs: ['7736325', '337436']
# Similarity Scores: [0.92713124 0.11025972]
#
#
# Query ID: 791631
# Ranked Passage IDs: ['7809042', '5023094']
# Similarity Scores: [0.7731393  0.08225649]
#
#
# Query ID: 792065
# Ranked Passage IDs: ['7733398', '6008289']
# Similarity Scores: [0.48724553 0.12236755]
#
#
# Query ID: 792184
# Ranked Passage IDs: ['7806825', '4698841']
# Similarity Scores: [0.56883746 0.12890542]
#
#
# Query ID: 792235
# Ranked Passage IDs: ['7746308', '7857610']
# Similarity Scores: [0.75211656 0.13605683]
#
#
# Query ID: 792438
# Ranked Passage IDs: ['7920933', '258050']
# Similarity Scores: [ 0.9075729  -0.04167054]
#
#
# Query ID: 792551
# Ranked Passage IDs: ['7827087', '6299855']
# Similarity Scores: [0.677051   0.11439733]
#
#
# Query ID: 79269
# Ranked Passage IDs: ['7889137', '6532672']
# Similarity Scores: [0.75232023 0.08228201]
#
#
# Query ID: 793019
# Ranked Passage IDs: ['7959387', '5286578']
# Similarity Scores: [0.66748965 0.0952847 ]
#
#
# Query ID: 793040
# Ranked Passage IDs: ['1820847', '3041965']
# Similarity Scores: [0.70176303 0.0758034 ]
#
#
# Query ID: 793099
# Ranked Passage IDs: ['7929199', '641882']
# Similarity Scores: [0.7529874  0.12162957]
#
#
# Query ID: 793336
# Ranked Passage IDs: ['7853645', '1056311']
# Similarity Scores: [0.77085334 0.13688882]
#
#
# Query ID: 793960
# Ranked Passage IDs: ['7850600', '5014449']
# Similarity Scores: [0.83227503 0.07758532]
#
#
# Query ID: 794328
# Ranked Passage IDs: ['7740945', '5652263']
# Similarity Scores: [0.6861765  0.11607143]
#
#
# Query ID: 794334
# Ranked Passage IDs: ['7870758', '6984341']
# Similarity Scores: [0.91832525 0.00478613]
#
#
# Query ID: 794667
# Ranked Passage IDs: ['7891851', '595599']
# Similarity Scores: [ 0.885766  -0.0305805]
#
#
# Query ID: 795048
# Ranked Passage IDs: ['7784486', '6760312']
# Similarity Scores: [0.9291096  0.02176853]
#
#
# Query ID: 795821
# Ranked Passage IDs: ['1924751', '3860662']
# Similarity Scores: [0.9195416  0.06666392]
#
#
# Query ID: 795878
# Ranked Passage IDs: ['7791697', '7666531']
# Similarity Scores: [0.8720518  0.01414136]
#
#
# Query ID: 795943
# Ranked Passage IDs: ['7910147', '2239819']
# Similarity Scores: [0.94765735 0.10649976]
#
#
# Query ID: 796209
# Ranked Passage IDs: ['7953416', '6168988']
# Similarity Scores: [0.90073055 0.2748125 ]
#
#
# Query ID: 79651
# Ranked Passage IDs: ['7296959', '3599331']
# Similarity Scores: [0.87173706 0.06755903]
#
#
# Query ID: 797426
# Ranked Passage IDs: ['7836245', '799824']
# Similarity Scores: [0.64792496 0.10889576]
#
#
# Query ID: 797600
# Ranked Passage IDs: ['7838256', '7863218']
# Similarity Scores: [ 0.801889   -0.00682543]
#
#
# Query ID: 798190
# Ranked Passage IDs: ['7913454', '7301355']
# Similarity Scores: [0.8168981  0.17672452]
#
#
# Query ID: 79831
# Ranked Passage IDs: ['170827', '2945504']
# Similarity Scores: [0.74242    0.05959104]
#
#
# Query ID: 798417
# Ranked Passage IDs: ['7929939', '6208598']
# Similarity Scores: [0.93777543 0.10896587]
#
#
# Query ID: 798425
# Ranked Passage IDs: ['7782730', '8601069']
# Similarity Scores: [0.7260796 0.1226077]
#
#
# Query ID: 798703
# Ranked Passage IDs: ['7816976', '1128128']
# Similarity Scores: [ 0.5181518  -0.04826873]
#
#
# Query ID: 798945
# Ranked Passage IDs: ['2652138', '1468963']
# Similarity Scores: [0.6739403  0.05768253]
#
#
# Query ID: 799195
# Ranked Passage IDs: ['7736472', '16764']
# Similarity Scores: [0.83550626 0.19992542]
#
#
# Query ID: 79936
# Ranked Passage IDs: ['5575183', '8227143']
# Similarity Scores: [0.6275514  0.11272639]
#
#
# Query ID: 799727
# Ranked Passage IDs: ['7753021', '838933']
# Similarity Scores: [0.7711982  0.10195103]
#
#
# Query ID: 799849
# Ranked Passage IDs: ['7950163', '8074447']
# Similarity Scores: [0.68580556 0.16404173]
#
#
# Query ID: 79992
# Ranked Passage IDs: ['7328666', '7207749']
# Similarity Scores: [0.6035786  0.20969236]
#
#
# Query ID: 800184
# Ranked Passage IDs: ['7897174', '1318467']
# Similarity Scores: [0.68155473 0.0988349 ]
#
#
# Query ID: 800479
# Ranked Passage IDs: ['7730098', '4532570']
# Similarity Scores: [0.64970183 0.11712059]
#
#
# Query ID: 800561
# Ranked Passage IDs: ['7593896', '7252205']
# Similarity Scores: [0.6733161  0.03171714]
#
#
# Query ID: 80187
# Ranked Passage IDs: ['7313749', '5584806']
# Similarity Scores: [0.7442872  0.01824425]
#
#
# Query ID: 801911
# Ranked Passage IDs: ['7929465', '273567']
# Similarity Scores: [ 7.3576343e-01 -2.7036408e-04]
#
#
# Query ID: 80294
# Ranked Passage IDs: ['5052582', '1468545']
# Similarity Scores: [0.6472069  0.00827076]
#
#
# Query ID: 803162
# Ranked Passage IDs: ['7943097', '5041949']
# Similarity Scores: [0.7765743  0.11310676]
#
#
# Query ID: 803395
# Ranked Passage IDs: ['7768075', '6601188']
# Similarity Scores: [0.8996895  0.13926561]
#
#
# Query ID: 804139
# Ranked Passage IDs: ['7740778', '930366']
# Similarity Scores: [0.9028358  0.03181275]
#
#
# Query ID: 804308
# Ranked Passage IDs: ['7961897', '2884632']
# Similarity Scores: [0.8167621  0.04465288]
#
#
# Query ID: 806771
# Ranked Passage IDs: ['7798798', '7655556']
# Similarity Scores: [0.85336274 0.03938024]
#
#
# Query ID: 806974
# Ranked Passage IDs: ['7831540', '4245274']
# Similarity Scores: [0.6344801  0.03060175]
#
#
# Query ID: 807162
# Ranked Passage IDs: ['2916869', '5352369']
# Similarity Scores: [0.87378585 0.13587677]
#
#
# Query ID: 80747
# Ranked Passage IDs: ['7309953', '183063']
# Similarity Scores: [ 0.746207   -0.01853155]
#
#
# Query ID: 807880
# Ranked Passage IDs: ['7821306', '6382323']
# Similarity Scores: [0.6545859 0.0845933]
#
#
# Query ID: 808019
# Ranked Passage IDs: ['7761218', '2605436']
# Similarity Scores: [0.7354595  0.12159188]
#
#
# Query ID: 808200
# Ranked Passage IDs: ['7956784', '2419470']
# Similarity Scores: [0.853933   0.12055124]
#
#
# Query ID: 808362
# Ranked Passage IDs: ['7730127', '7869040']
# Similarity Scores: [0.78467625 0.17206559]
#
#
# Query ID: 808718
# Ranked Passage IDs: ['7273915', '2527006']
# Similarity Scores: [0.8535204  0.02675034]
#
#
# Query ID: 809133
# Ranked Passage IDs: ['1035928', '7902206']
# Similarity Scores: [0.8894663  0.18089361]
#
#
# Query ID: 809676
# Ranked Passage IDs: ['2026012', '1555930']
# Similarity Scores: [0.684003   0.26267225]
#
#
# Query ID: 810235
# Ranked Passage IDs: ['7380629', '460777']
# Similarity Scores: [0.5099017 0.1121325]
#
#
# Query ID: 810320
# Ranked Passage IDs: ['789261', '273841']
# Similarity Scores: [ 0.66905975 -0.05732133]
#
#
# Query ID: 810394
# Ranked Passage IDs: ['764872', '7966805', '3656790', '2723418']
# Similarity Scores: [0.86686563 0.79296154 0.13873482 0.10386375]
#
#
# Query ID: 811582
# Ranked Passage IDs: ['2547755', '1740587']
# Similarity Scores: [0.71557623 0.03868232]
#
#
# Query ID: 811624
# Ranked Passage IDs: ['7900290', '6085796']
# Similarity Scores: [0.8660344 0.0518086]
#
#
# Query ID: 812028
# Ranked Passage IDs: ['2352871', '6488642']
# Similarity Scores: [0.69348    0.13000697]
#
#
# Query ID: 812538
# Ranked Passage IDs: ['954000', '7831951']
# Similarity Scores: [0.7943208  0.11356562]
#
#
# Query ID: 812545
# Ranked Passage IDs: ['7796102', '1942852']
# Similarity Scores: [0.80737716 0.29102057]
#
#
# Query ID: 813112
# Ranked Passage IDs: ['7743394', '2202390']
# Similarity Scores: [0.60661495 0.06282952]
#
#
# Query ID: 813339
# Ranked Passage IDs: ['7859370', '5149331']
# Similarity Scores: [0.79188746 0.01594046]
#
#
# Query ID: 813540
# Ranked Passage IDs: ['7966643', '7081244']
# Similarity Scores: [0.9069473  0.06236644]
#
#
# Query ID: 814139
# Ranked Passage IDs: ['7861368', '7972860']
# Similarity Scores: [0.79386663 0.17290586]
#
#
# Query ID: 814345
# Ranked Passage IDs: ['7757701', '7920339']
# Similarity Scores: [0.7813613  0.08375847]
#
#
# Query ID: 81457
# Ranked Passage IDs: ['7797606', '214441']
# Similarity Scores: [0.5713981  0.11029472]
#
#
# Query ID: 814919
# Ranked Passage IDs: ['2145569', '2358692']
# Similarity Scores: [0.9447469 0.1204439]
#
#
# Query ID: 814937
# Ranked Passage IDs: ['7797329', '5403536']
# Similarity Scores: [0.7650511 0.1692105]
#
#
# Query ID: 814987
# Ranked Passage IDs: ['7719368', '8184627']
# Similarity Scores: [0.73004794 0.18798701]
#
#
# Query ID: 815174
# Ranked Passage IDs: ['7828735', '3766472']
# Similarity Scores: [ 0.90219194 -0.03744473]
#
#
# Query ID: 815262
# Ranked Passage IDs: ['7812746', '8134702']
# Similarity Scores: [0.69399506 0.027136  ]
#
#
# Query ID: 815294
# Ranked Passage IDs: ['7878636', '6351284']
# Similarity Scores: [0.61834896 0.17747623]
#
#
# Query ID: 815420
# Ranked Passage IDs: ['7914307', '2411371']
# Similarity Scores: [0.6332828  0.14302972]
#
#
# Query ID: 81571
# Ranked Passage IDs: ['7071943', '7593544']
# Similarity Scores: [0.6165265  0.02393111]
#
#
# Query ID: 815714
# Ranked Passage IDs: ['7720666', '6739238']
# Similarity Scores: [0.87093854 0.21518345]
#
#
# Query ID: 815916
# Ranked Passage IDs: ['7880174', '8698049']
# Similarity Scores: [0.8618347  0.10986305]
#
#
# Query ID: 816111
# Ranked Passage IDs: ['7870760', '7004724']
# Similarity Scores: [ 0.60040605 -0.00244744]
#
#
# Query ID: 816235
# Ranked Passage IDs: ['7751928', '1744561']
# Similarity Scores: [0.9204207 0.120416 ]
#
#
# Query ID: 816388
# Ranked Passage IDs: ['7749293', '6543842']
# Similarity Scores: [0.6945556 0.0078488]
#
#
# Query ID: 816396
# Ranked Passage IDs: ['7751527', '994756']
# Similarity Scores: [0.87794507 0.16502105]
#
#
# Query ID: 81663
# Ranked Passage IDs: ['7329054', '797356']
# Similarity Scores: [0.827783   0.07684083]
#
#
# Query ID: 817128
# Ranked Passage IDs: ['7813984', '6983874']
# Similarity Scores: [0.8331315  0.05432472]
#
#
# Query ID: 817239
# Ranked Passage IDs: ['7879728', '3200639']
# Similarity Scores: [0.82761586 0.1443606 ]
#
#
# Query ID: 817387
# Ranked Passage IDs: ['7964290', '6784614']
# Similarity Scores: [0.81352824 0.2091422 ]
#
#
# Query ID: 817514
# Ranked Passage IDs: ['7961615', '2998821']
# Similarity Scores: [0.79528296 0.08482353]
#
#
# Query ID: 817703
# Ranked Passage IDs: ['7943626', '1558797']
# Similarity Scores: [0.8390622 0.2176682]
#
#
# Query ID: 817850
# Ranked Passage IDs: ['7722425', '3123426']
# Similarity Scores: [0.868905   0.30936515]
#
#
# Query ID: 817939
# Ranked Passage IDs: ['7882934', '6838871']
# Similarity Scores: [0.59831274 0.03337326]
#
#
# Query ID: 818080
# Ranked Passage IDs: ['7855213', '1245765']
# Similarity Scores: [0.8104064  0.36495966]
#
#
# Query ID: 818421
# Ranked Passage IDs: ['7972335', '2541974']
# Similarity Scores: [0.82085395 0.11317279]
#
#
# Query ID: 818476
# Ranked Passage IDs: ['7965367', '3769080']
# Similarity Scores: [ 0.8412274  -0.07955151]
#
#
# Query ID: 81861
# Ranked Passage IDs: ['1623640', '8300648']
# Similarity Scores: [0.7214147  0.06616423]
#
#
# Query ID: 818642
# Ranked Passage IDs: ['7941052', '8041180']
# Similarity Scores: [0.6676797  0.16058221]
#
#
# Query ID: 819395
# Ranked Passage IDs: ['7941559', '3136835']
# Similarity Scores: [0.24223879 0.12911125]
#
#
# Query ID: 819573
# Ranked Passage IDs: ['7779331', '3293939']
# Similarity Scores: [ 0.6750144  -0.00373926]
#
#
# Query ID: 819683
# Ranked Passage IDs: ['7885487', '1279367']
# Similarity Scores: [0.800359   0.15423837]
#
#
# Query ID: 820206
# Ranked Passage IDs: ['7679441', '203064']
# Similarity Scores: [0.854503   0.05420639]
#
#
# Query ID: 820322
# Ranked Passage IDs: ['7886391', '1618422']
# Similarity Scores: [0.9211955  0.09789019]
#
#
# Query ID: 821068
# Ranked Passage IDs: ['7974972', '8432958']
# Similarity Scores: [0.7574259  0.04748425]
#
#
# Query ID: 821245
# Ranked Passage IDs: ['7882188', '3037858']
# Similarity Scores: [0.76624006 0.19236651]
#
#
# Query ID: 821328
# Ranked Passage IDs: ['7796179', '4237349']
# Similarity Scores: [0.7306989  0.07489099]
#
#
# Query ID: 821480
# Ranked Passage IDs: ['2204771', '5172432']
# Similarity Scores: [0.74146324 0.10556775]
#
#
# Query ID: 821486
# Ranked Passage IDs: ['7943261', '3517937']
# Similarity Scores: [0.7230662  0.09920587]
#
#
# Query ID: 821657
# Ranked Passage IDs: ['7947365', '4028767']
# Similarity Scores: [0.41671667 0.08541206]
#
#
# Query ID: 821938
# Ranked Passage IDs: ['2181848', '1736358']
# Similarity Scores: [0.73015934 0.16316934]
#
#
# Query ID: 822059
# Ranked Passage IDs: ['7648225', '4964929']
# Similarity Scores: [0.8407163  0.07089663]
#
#
# Query ID: 822261
# Ranked Passage IDs: ['155874', '8472758']
# Similarity Scores: [0.73788565 0.37290707]
#
#
# Query ID: 822492
# Ranked Passage IDs: ['7801640', '7167914']
# Similarity Scores: [0.7419503  0.30946332]
#
#
# Query ID: 82359
# Ranked Passage IDs: ['7318305', '1100625']
# Similarity Scores: [0.8374821  0.02441589]
#
#
# Query ID: 824559
# Ranked Passage IDs: ['7825164', '4555854']
# Similarity Scores: [0.7000678  0.10169245]
#
#
# Query ID: 824640
# Ranked Passage IDs: ['7976667', '3381142']
# Similarity Scores: [0.8462124  0.03408769]
#
#
# Query ID: 825357
# Ranked Passage IDs: ['7781113', '7858726']
# Similarity Scores: [0.59002864 0.10945463]
#
#
# Query ID: 825726
# Ranked Passage IDs: ['7855152', '1839615']
# Similarity Scores: [0.7076113  0.01253598]
#
#
# Query ID: 825858
# Ranked Passage IDs: ['7852790', '5141803']
# Similarity Scores: [0.59735435 0.08356448]
#
#
# Query ID: 825920
# Ranked Passage IDs: ['3226546', '2779883']
# Similarity Scores: [0.92884326 0.00801609]
#
#
# Query ID: 826105
# Ranked Passage IDs: ['7938994', '8514620']
# Similarity Scores: [0.4765979  0.26450375]
#
#
# Query ID: 826308
# Ranked Passage IDs: ['7949220', '2308521']
# Similarity Scores: [0.6810071  0.15719782]
#
#
# Query ID: 826613
# Ranked Passage IDs: ['3927860', '4625498']
# Similarity Scores: [0.8731029  0.16363607]
#
#
# Query ID: 828087
# Ranked Passage IDs: ['7907858', '1334419']
# Similarity Scores: [0.8373066  0.06127271]
#
#
# Query ID: 828214
# Ranked Passage IDs: ['6910071', '7378846']
# Similarity Scores: [0.726961   0.11395827]
#
#
# Query ID: 82826
# Ranked Passage IDs: ['7861497', '8397114']
# Similarity Scores: [0.8152192 0.0610147]
#
#
# Query ID: 828360
# Ranked Passage IDs: ['7978317', '618042']
# Similarity Scores: [0.90699506 0.12359609]
#
#
# Query ID: 828588
# Ranked Passage IDs: ['2806207', '1360121']
# Similarity Scores: [0.8034347 0.2031152]
#
#
# Query ID: 828596
# Ranked Passage IDs: ['7859102', '6380222']
# Similarity Scores: [ 0.8675932  -0.01056312]
#
#
# Query ID: 829049
# Ranked Passage IDs: ['7746185', '3404049']
# Similarity Scores: [0.85232496 0.05338244]
#
#
# Query ID: 829072
# Ranked Passage IDs: ['3139316', '5936585']
# Similarity Scores: [0.8237547  0.26757345]
#
#
# Query ID: 829180
# Ranked Passage IDs: ['7877432', '174629']
# Similarity Scores: [ 0.7333243  -0.00984339]
#
#
# Query ID: 829574
# Ranked Passage IDs: ['7890517', '4702943']
# Similarity Scores: [0.90652776 0.02601342]
#
#
# Query ID: 82972
# Ranked Passage IDs: ['7581077', '4503079']
# Similarity Scores: [0.9132954  0.49121723]
#
#
# Query ID: 830401
# Ranked Passage IDs: ['7868401', '5487658']
# Similarity Scores: [0.895579   0.09853535]
#
#
# Query ID: 830449
# Ranked Passage IDs: ['2895176', '156920']
# Similarity Scores: [0.8559483 0.0846648]
#
#
# Query ID: 830461
# Ranked Passage IDs: ['3232957', '6134477']
# Similarity Scores: [0.8843474  0.12804534]
#
#
# Query ID: 831052
# Ranked Passage IDs: ['4231748', '3356975']
# Similarity Scores: [ 0.78626984 -0.00164619]
#
#
# Query ID: 831072
# Ranked Passage IDs: ['7928719', '7087844']
# Similarity Scores: [0.8043663  0.14644405]
#
#
# Query ID: 831480
# Ranked Passage IDs: ['7800276', '2927602']
# Similarity Scores: [0.9151071 0.2953684]
#
#
# Query ID: 832173
# Ranked Passage IDs: ['240764', '7273621']
# Similarity Scores: [0.7345413  0.10686562]
#
#
# Query ID: 832330
# Ranked Passage IDs: ['7730391', '1066439']
# Similarity Scores: [0.8194139 0.0046729]
#
#
# Query ID: 832370
# Ranked Passage IDs: ['7779565', '4461270']
# Similarity Scores: [0.7813781  0.17858376]
#
#
# Query ID: 832498
# Ranked Passage IDs: ['7944176', '4725370']
# Similarity Scores: [0.67446107 0.04615087]
#
#
# Query ID: 832643
# Ranked Passage IDs: ['3525400', '7667453']
# Similarity Scores: [0.8749716  0.12688753]
#
#
# Query ID: 83265
# Ranked Passage IDs: ['7383643', '675614']
# Similarity Scores: [0.68524915 0.05369386]
#
#
# Query ID: 83336
# Ranked Passage IDs: ['7983669', '3362795']
# Similarity Scores: [0.87517697 0.06231248]
#
#
# Query ID: 833384
# Ranked Passage IDs: ['7838031', '4618222']
# Similarity Scores: [0.5709056 0.1481059]
#
#
# Query ID: 833579
# Ranked Passage IDs: ['7924840', '2859621']
# Similarity Scores: [0.7679741  0.03477406]
#
#
# Query ID: 833624
# Ranked Passage IDs: ['7932431', '7907534']
# Similarity Scores: [0.6560536  0.05189525]
#
#
# Query ID: 834093
# Ranked Passage IDs: ['7965619', '7513598']
# Similarity Scores: [0.8136873  0.23298061]
#
#
# Query ID: 834119
# Ranked Passage IDs: ['7979155', '4935191']
# Similarity Scores: [ 0.8587868  -0.03135786]
#
#
# Query ID: 834251
# Ranked Passage IDs: ['7884951', '7787666']
# Similarity Scores: [ 0.85217196 -0.05966426]
#
#
# Query ID: 834787
# Ranked Passage IDs: ['7795929', '7357022']
# Similarity Scores: [0.7971123  0.06684745]
#
#
# Query ID: 834803
# Ranked Passage IDs: ['7755756', '2407990']
# Similarity Scores: [0.6659513  0.02398676]
#
#
# Query ID: 835704
# Ranked Passage IDs: ['7794279', '6086557']
# Similarity Scores: [ 0.7365941  -0.02598029]
#
#
# Query ID: 835757
# Ranked Passage IDs: ['7850925', '128277']
# Similarity Scores: [0.52188355 0.06187849]
#
#
# Query ID: 835996
# Ranked Passage IDs: ['7824302', '8662313']
# Similarity Scores: [0.8349827  0.08734944]
#
#
# Query ID: 836098
# Ranked Passage IDs: ['7902859', '2902574']
# Similarity Scores: [0.81533843 0.17054017]
#
#
# Query ID: 837007
# Ranked Passage IDs: ['7816075', '5595090']
# Similarity Scores: [ 0.8358569 -0.0229574]
#
#
# Query ID: 837048
# Ranked Passage IDs: ['7752930', '2903628']
# Similarity Scores: [0.7775819  0.06102012]
#
#
# Query ID: 837192
# Ranked Passage IDs: ['1809322', '948210']
# Similarity Scores: [0.7023896  0.01844769]
#
#
# Query ID: 837252
# Ranked Passage IDs: ['7902022', '82110']
# Similarity Scores: [0.83656067 0.02579982]
#
#
# Query ID: 837680
# Ranked Passage IDs: ['7760326', '8192900']
# Similarity Scores: [0.8129207 0.1378715]
#
#
# Query ID: 837681
# Ranked Passage IDs: ['7794679', '6907309']
# Similarity Scores: [0.78876466 0.01498412]
#
#
# Query ID: 837982
# Ranked Passage IDs: ['7830437', '2786017']
# Similarity Scores: [0.89619493 0.18433635]
#
#
# Query ID: 838267
# Ranked Passage IDs: ['7860279', '3673231']
# Similarity Scores: [0.8487461  0.12283973]
#
#
# Query ID: 838525
# Ranked Passage IDs: ['7872260', '4060272']
# Similarity Scores: [0.7618362  0.06139143]
#
#
# Query ID: 838571
# Ranked Passage IDs: ['7853359', '3573004']
# Similarity Scores: [ 0.7438055  -0.05342391]
#
#
# Query ID: 838682
# Ranked Passage IDs: ['2845524', '6818900']
# Similarity Scores: [0.87802315 0.06002711]
#
#
# Query ID: 838689
# Ranked Passage IDs: ['7907779', '7823672']
# Similarity Scores: [0.7828655  0.17424136]
#
#
# Query ID: 838823
# Ranked Passage IDs: ['7954208', '5282227']
# Similarity Scores: [ 0.6623739  -0.05327601]
#
#
# Query ID: 83885
# Ranked Passage IDs: ['7459814', '4807828']
# Similarity Scores: [0.9599331 0.0451358]
#
#
# Query ID: 839551
# Ranked Passage IDs: ['7934452', '6908484']
# Similarity Scores: [0.87423766 0.21276878]
#
#
# Query ID: 840053
# Ranked Passage IDs: ['529990', '6202735']
# Similarity Scores: [ 0.92197317 -0.0776656 ]
#
#
# Query ID: 840061
# Ranked Passage IDs: ['7780984', '4423447']
# Similarity Scores: [0.89869666 0.0348726 ]
#
#
# Query ID: 840096
# Ranked Passage IDs: ['7975241', '1784262']
# Similarity Scores: [0.79194933 0.14025536]
#
#
# Query ID: 840445
# Ranked Passage IDs: ['7858303', '5317241']
# Similarity Scores: [0.8831996  0.21868853]
#
#
# Query ID: 840532
# Ranked Passage IDs: ['7839752', '928653']
# Similarity Scores: [0.88204545 0.37279436]
#
#
# Query ID: 840711
# Ranked Passage IDs: ['4217093', '7455871']
# Similarity Scores: [0.7978502 0.0187337]
#
#
# Query ID: 84073
# Ranked Passage IDs: ['7401155', '2827969']
# Similarity Scores: [0.7484821 0.0558904]
#
#
# Query ID: 841055
# Ranked Passage IDs: ['7801992', '7586256']
# Similarity Scores: [0.8526753  0.05529067]
#
#
# Query ID: 841404
# Ranked Passage IDs: ['7917844', '8381287']
# Similarity Scores: [ 0.7502293  -0.00626048]
#
#
# Query ID: 841521
# Ranked Passage IDs: ['7780242', '5794448']
# Similarity Scores: [0.7082068 0.0973593]
#
#
# Query ID: 841551
# Ranked Passage IDs: ['7771731', '8262399']
# Similarity Scores: [0.7401828  0.09934215]
#
#
# Query ID: 841608
# Ranked Passage IDs: ['7950154', '3952184']
# Similarity Scores: [0.6368292  0.04437309]
#
#
# Query ID: 8431
# Ranked Passage IDs: ['7910791', '7019922']
# Similarity Scores: [0.86066246 0.09793977]
#
#
# Query ID: 843164
# Ranked Passage IDs: ['7752802', '444760']
# Similarity Scores: [0.9305812  0.14762299]
#
#
# Query ID: 843628
# Ranked Passage IDs: ['7762432', '5320140']
# Similarity Scores: [0.81668305 0.15298823]
#
#
# Query ID: 84388
# Ranked Passage IDs: ['7879592', '3927365']
# Similarity Scores: [0.81301874 0.19989291]
#
#
# Query ID: 844075
# Ranked Passage IDs: ['7977345', '1959003']
# Similarity Scores: [0.77633923 0.07761762]
#
#
# Query ID: 844233
# Ranked Passage IDs: ['7736813', '6658794']
# Similarity Scores: [0.4711895  0.21518694]
#
#
# Query ID: 844897
# Ranked Passage IDs: ['7935972', '5033141']
# Similarity Scores: [0.7943954  0.02987672]
#
#
# Query ID: 845364
# Ranked Passage IDs: ['7823482', '2474896']
# Similarity Scores: [0.95051503 0.04687989]
#
#
# Query ID: 845678
# Ranked Passage IDs: ['4347541', '3185591']
# Similarity Scores: [0.84329677 0.06791262]
#
#
# Query ID: 845790
# Ranked Passage IDs: ['7866647', '3898391']
# Similarity Scores: [0.9014523  0.17274493]
#
#
# Query ID: 846467
# Ranked Passage IDs: ['7943536', '739811']
# Similarity Scores: [8.210146e-01 6.103903e-05]
#
#
# Query ID: 84659
# Ranked Passage IDs: ['4104204', '7631447', '2102815', '6996803']
# Similarity Scores: [0.83251476 0.66697955 0.13963605 0.02395636]
#
#
# Query ID: 847157
# Ranked Passage IDs: ['7857031', '5609489']
# Similarity Scores: [0.75769144 0.08020888]
#
#
# Query ID: 847172
# Ranked Passage IDs: ['7811838', '5273228']
# Similarity Scores: [0.8972156  0.05004469]
#
#
# Query ID: 847173
# Ranked Passage IDs: ['7830716', '2839144']
# Similarity Scores: [0.79264754 0.08507667]
#
#
# Query ID: 847599
# Ranked Passage IDs: ['7863605', '4820818']
# Similarity Scores: [0.7501133  0.10898838]
#
#
# Query ID: 847736
# Ranked Passage IDs: ['2315342', '2566569']
# Similarity Scores: [ 0.7352874  -0.09884196]
#
#
# Query ID: 848100
# Ranked Passage IDs: ['7796454', '1241827']
# Similarity Scores: [0.6377446 0.186646 ]
#
#
# Query ID: 84813
# Ranked Passage IDs: ['50758', '2896697']
# Similarity Scores: [0.71135587 0.11598455]
#
#
# Query ID: 848402
# Ranked Passage IDs: ['7784762', '386282']
# Similarity Scores: [ 0.77758944 -0.00445849]
#
#
# Query ID: 848785
# Ranked Passage IDs: ['7859392', '7813211']
# Similarity Scores: [6.9525188e-01 3.4845754e-04]
#
#
# Query ID: 849227
# Ranked Passage IDs: ['7817612', '1629762']
# Similarity Scores: [0.8556401  0.17587885]
#
#
# Query ID: 84984
# Ranked Passage IDs: ['275988', '5696694']
# Similarity Scores: [0.84167665 0.06257988]
#
#
# Query ID: 850098
# Ranked Passage IDs: ['6766049', '3678992']
# Similarity Scores: [0.7062998  0.01304259]
#
#
# Query ID: 850197
# Ranked Passage IDs: ['7875784', '269637']
# Similarity Scores: [0.87066936 0.0722698 ]
#
#
# Query ID: 85061
# Ranked Passage IDs: ['7829141', '7829144', '4131826', '4981076']
# Similarity Scores: [0.61815435 0.5541714  0.13657272 0.07750229]
#
#
# Query ID: 85063
# Ranked Passage IDs: ['7375710', '6215323']
# Similarity Scores: [ 0.927335   -0.01103708]
#
#
# Query ID: 850733
# Ranked Passage IDs: ['7924480', '701872']
# Similarity Scores: [7.3124975e-01 1.9650903e-04]
#
#
# Query ID: 851304
# Ranked Passage IDs: ['7907398', '8395362']
# Similarity Scores: [0.750909   0.08964148]
#
#
# Query ID: 851360
# Ranked Passage IDs: ['7720660', '1513737']
# Similarity Scores: [ 0.8811564  -0.00449163]
#
#
# Query ID: 851421
# Ranked Passage IDs: ['7868625', '5572947']
# Similarity Scores: [0.63539994 0.17312428]
#
#
# Query ID: 851822
# Ranked Passage IDs: ['7848546', '8773163']
# Similarity Scores: [0.92934614 0.08152007]
#
#
# Query ID: 852239
# Ranked Passage IDs: ['7802397', '7169650']
# Similarity Scores: [0.5898115  0.01084317]
#
#
# Query ID: 852578
# Ranked Passage IDs: ['1553535', '6184111']
# Similarity Scores: [0.7909526  0.03371573]
#
#
# Query ID: 852599
# Ranked Passage IDs: ['7904330', '43873']
# Similarity Scores: [0.90031105 0.05994851]
#
#
# Query ID: 852813
# Ranked Passage IDs: ['576172', '2293494']
# Similarity Scores: [0.91156036 0.04693332]
#
#
# Query ID: 853057
# Ranked Passage IDs: ['7723754', '7995434']
# Similarity Scores: [0.74395865 0.12881124]
#
#
# Query ID: 853344
# Ranked Passage IDs: ['1989069', '8577098']
# Similarity Scores: [ 0.6408461 -0.0467061]
#
#
# Query ID: 85368
# Ranked Passage IDs: ['7540427', '93542']
# Similarity Scores: [0.9271884  0.16047588]
#
#
# Query ID: 853699
# Ranked Passage IDs: ['7847466', '1828767']
# Similarity Scores: [0.9111165  0.08714166]
#
#
# Query ID: 853900
# Ranked Passage IDs: ['7935266', '6546378']
# Similarity Scores: [0.87386644 0.06545337]
#
#
# Query ID: 853977
# Ranked Passage IDs: ['1089642', '2236451']
# Similarity Scores: [ 0.8012936  -0.07454263]
#
#
# Query ID: 854413
# Ranked Passage IDs: ['5276995', '5657576']
# Similarity Scores: [ 0.63375205 -0.04515325]
#
#
# Query ID: 854444
# Ranked Passage IDs: ['7838069', '4839748']
# Similarity Scores: [0.6375206  0.10215881]
#
#
# Query ID: 85449
# Ranked Passage IDs: ['8007600', '600511']
# Similarity Scores: [0.8072472  0.17598358]
#
#
# Query ID: 854729
# Ranked Passage IDs: ['7783341', '745369']
# Similarity Scores: [0.8910024  0.07866455]
#
#
# Query ID: 854737
# Ranked Passage IDs: ['7974589', '2390714']
# Similarity Scores: [0.91118807 0.06167977]
#
#
# Query ID: 854758
# Ranked Passage IDs: ['7755293', '4622688']
# Similarity Scores: [0.8327478  0.20159966]
#
#
# Query ID: 854854
# Ranked Passage IDs: ['7751634', '6066590']
# Similarity Scores: [0.7279349  0.13230391]
#
#
# Query ID: 85503
# Ranked Passage IDs: ['7381985', '3317113']
# Similarity Scores: [0.91453934 0.05765043]
#
#
# Query ID: 855038
# Ranked Passage IDs: ['7892521', '6082832']
# Similarity Scores: [0.881533   0.11069959]
#
#
# Query ID: 85506
# Ranked Passage IDs: ['7537844', '6535971']
# Similarity Scores: [0.6012198  0.16046073]
#
#
# Query ID: 855291
# Ranked Passage IDs: ['7741210', '4381969']
# Similarity Scores: [0.9402837 0.1368602]
#
#
# Query ID: 855707
# Ranked Passage IDs: ['7748062', '461792']
# Similarity Scores: [0.90579134 0.16031909]
#
#
# Query ID: 855836
# Ranked Passage IDs: ['7831930', '186493']
# Similarity Scores: [0.9075277  0.21342078]
#
#
# Query ID: 856329
# Ranked Passage IDs: ['7935468', '8405210']
# Similarity Scores: [0.8222726  0.18423967]
#
#
# Query ID: 856568
# Ranked Passage IDs: ['1688293', '5953649']
# Similarity Scores: [0.5972138  0.13174288]
#
#
# Query ID: 85667
# Ranked Passage IDs: ['7385073', '5019335']
# Similarity Scores: [0.5570065  0.08887571]
#
#
# Query ID: 856943
# Ranked Passage IDs: ['7851118', '5531753']
# Similarity Scores: [0.7721791  0.04561295]
#
#
# Query ID: 857364
# Ranked Passage IDs: ['7869530', '4259826']
# Similarity Scores: [0.90205836 0.03870194]
#
#
# Query ID: 85839
# Ranked Passage IDs: ['1212469', '3221482']
# Similarity Scores: [ 0.91051924 -0.02297467]
#
#
# Query ID: 858685
# Ranked Passage IDs: ['7973013', '3601615']
# Similarity Scores: [0.87460667 0.10535454]
#
#
# Query ID: 85889
# Ranked Passage IDs: ['1760762', '3184224']
# Similarity Scores: [0.6318549  0.10407786]
#
#
# Query ID: 859102
# Ranked Passage IDs: ['7845317', '8665319']
# Similarity Scores: [0.8931465  0.02891982]
#
#
# Query ID: 859376
# Ranked Passage IDs: ['7917896', '7326202']
# Similarity Scores: [0.8354994 0.1681629]
#
#
# Query ID: 859420
# Ranked Passage IDs: ['7730900', '7685722']
# Similarity Scores: [0.633922   0.27796844]
#
#
# Query ID: 85954
# Ranked Passage IDs: ['7348202', '7348196', '6034246', '3343362']
# Similarity Scores: [0.7724152  0.69428575 0.15292706 0.02332952]
#
#
# Query ID: 859832
# Ranked Passage IDs: ['7741466', '1547731']
# Similarity Scores: [0.7168277  0.00873722]
#
#
# Query ID: 860078
# Ranked Passage IDs: ['7878984', '4963463']
# Similarity Scores: [0.7447543  0.17525074]
#
#
# Query ID: 86010
# Ranked Passage IDs: ['7788924', '7387616']
# Similarity Scores: [0.90808225 0.3152869 ]
#
#
# Query ID: 860313
# Ranked Passage IDs: ['7852264', '7514510']
# Similarity Scores: [0.7871476  0.10366794]
#
#
# Query ID: 8605
# Ranked Passage IDs: ['7371557', '3386928']
# Similarity Scores: [ 0.767605   -0.03595189]
#
#
# Query ID: 86094
# Ranked Passage IDs: ['7299269', '7985663']
# Similarity Scores: [0.7099865  0.10135522]
#
#
# Query ID: 860952
# Ranked Passage IDs: ['7957303', '7695127']
# Similarity Scores: [0.42278516 0.4095598 ]
#
#
# Query ID: 861396
# Ranked Passage IDs: ['7731630', '8774950']
# Similarity Scores: [ 0.85998726 -0.04503968]
#
#
# Query ID: 861818
# Ranked Passage IDs: ['7750281', '4317522']
# Similarity Scores: [0.86734563 0.16826235]
#
#
# Query ID: 862110
# Ranked Passage IDs: ['7918430', '5522081']
# Similarity Scores: [0.75995415 0.10923167]
#
#
# Query ID: 862244
# Ranked Passage IDs: ['7919939', '1129788']
# Similarity Scores: [0.8532527  0.18480259]
#
#
# Query ID: 862345
# Ranked Passage IDs: ['7791010', '1523518']
# Similarity Scores: [0.6385711  0.01587026]
#
#
# Query ID: 862366
# Ranked Passage IDs: ['7836487', '5172677']
# Similarity Scores: [0.89207226 0.0197694 ]
#
#
# Query ID: 862573
# Ranked Passage IDs: ['7790377', '8227413']
# Similarity Scores: [0.7866553  0.12622711]
#
#
# Query ID: 863738
# Ranked Passage IDs: ['7956664', '2866718']
# Similarity Scores: [0.84083056 0.18475632]
#
#
# Query ID: 864502
# Ranked Passage IDs: ['7913909', '2966959']
# Similarity Scores: [ 5.071089e-01 -2.155402e-04]
#
#
# Query ID: 864719
# Ranked Passage IDs: ['7942685', '5513699']
# Similarity Scores: [ 0.4979176  -0.08488545]
#
#
# Query ID: 864767
# Ranked Passage IDs: ['7926711', '3812913']
# Similarity Scores: [0.5736462  0.15926924]
#
#
# Query ID: 864953
# Ranked Passage IDs: ['7942006', '4442735']
# Similarity Scores: [ 0.90562785 -0.01677899]
#
#
# Query ID: 864955
# Ranked Passage IDs: ['7749424', '5636552']
# Similarity Scores: [0.8333071  0.02871818]
#
#
# Query ID: 865310
# Ranked Passage IDs: ['7807234', '5450136']
# Similarity Scores: [0.3613529  0.09272689]
#
#
# Query ID: 865370
# Ranked Passage IDs: ['1103641', '8538829']
# Similarity Scores: [0.86519444 0.16286166]
#
#
# Query ID: 865384
# Ranked Passage IDs: ['6511070', '7285413']
# Similarity Scores: [0.89830303 0.31203058]
#
#
# Query ID: 865505
# Ranked Passage IDs: ['7830117', '1893323']
# Similarity Scores: [0.9182359  0.07903043]
#
#
# Query ID: 865732
# Ranked Passage IDs: ['7929786', '8665768']
# Similarity Scores: [ 0.8156922 -0.0135779]
#
#
# Query ID: 865847
# Ranked Passage IDs: ['7880727', '2027565']
# Similarity Scores: [0.50609696 0.21074224]
#
#
# Query ID: 866387
# Ranked Passage IDs: ['4614907', '4780851']
# Similarity Scores: [0.55887735 0.19461678]
#
#
# Query ID: 866526
# Ranked Passage IDs: ['7807341', '5292292']
# Similarity Scores: [0.91623366 0.03223772]
#
#
# Query ID: 867580
# Ranked Passage IDs: ['7729611', '5032588']
# Similarity Scores: [0.70428646 0.06250706]
#
#
# Query ID: 868084
# Ranked Passage IDs: ['7836900', '1305072']
# Similarity Scores: [ 0.9084468  -0.00630767]
#
#
# Query ID: 868274
# Ranked Passage IDs: ['7831467', '8248454']
# Similarity Scores: [0.42557573 0.05443366]
#
#
# Query ID: 868487
# Ranked Passage IDs: ['7861554', '5390789']
# Similarity Scores: [0.79391384 0.07036031]
#
#
# Query ID: 868594
# Ranked Passage IDs: ['7846219', '7670913']
# Similarity Scores: [0.3973652  0.06382408]
#
#
# Query ID: 868941
# Ranked Passage IDs: ['7967297', '2654227']
# Similarity Scores: [0.89315003 0.08653952]
#
#
# Query ID: 869269
# Ranked Passage IDs: ['3433494', '6515059']
# Similarity Scores: [0.8341191  0.02176383]
#
#
# Query ID: 869270
# Ranked Passage IDs: ['6086617', '4316912']
# Similarity Scores: [0.8430434 0.2663718]
#
#
# Query ID: 869465
# Ranked Passage IDs: ['7894387', '8293202']
# Similarity Scores: [0.8509818  0.00807524]
#
#
# Query ID: 870107
# Ranked Passage IDs: ['7945464', '4333141']
# Similarity Scores: [0.7684156  0.06511902]
#
#
# Query ID: 870765
# Ranked Passage IDs: ['7888089', '2585930']
# Similarity Scores: [0.8189485  0.52798945]
#
#
# Query ID: 870861
# Ranked Passage IDs: ['7719280', '4814136']
# Similarity Scores: [0.8129276  0.15792935]
#
#
# Query ID: 871233
# Ranked Passage IDs: ['7888844', '2320795']
# Similarity Scores: [0.7288553  0.07002114]
#
#
# Query ID: 87139
# Ranked Passage IDs: ['7987504', '885490']
# Similarity Scores: [0.8697979 0.1500299]
#
#
# Query ID: 871459
# Ranked Passage IDs: ['7895267', '2235474']
# Similarity Scores: [0.8597046  0.07700871]
#
#
# Query ID: 871835
# Ranked Passage IDs: ['7719620', '7727687']
# Similarity Scores: [0.6827365 0.1865348]
#
#
# Query ID: 871888
# Ranked Passage IDs: ['7877480', '772068']
# Similarity Scores: [0.64406925 0.12838493]
#
#
# Query ID: 872125
# Ranked Passage IDs: ['7881268', '7625045']
# Similarity Scores: [0.9450677  0.02032657]
#
#
# Query ID: 872166
# Ranked Passage IDs: ['7727353', '5598171']
# Similarity Scores: [0.76601845 0.0727604 ]
#
#
# Query ID: 87239
# Ranked Passage IDs: ['2476369', '2535934']
# Similarity Scores: [0.67117035 0.14652342]
#
#
# Query ID: 872398
# Ranked Passage IDs: ['7770428', '1799521']
# Similarity Scores: [0.70725274 0.16462806]
#
#
# Query ID: 872855
# Ranked Passage IDs: ['7937399', '6421043']
# Similarity Scores: [0.75345165 0.22763468]
#
#
# Query ID: 872856
# Ranked Passage IDs: ['7948375', '7843946']
# Similarity Scores: [0.47989413 0.06167769]
#
#
# Query ID: 872947
# Ranked Passage IDs: ['1233161', '5005569']
# Similarity Scores: [0.68470407 0.06625924]
#
#
# Query ID: 87367
# Ranked Passage IDs: ['670962', '6422334']
# Similarity Scores: [0.8203294  0.11166102]
#
#
# Query ID: 873886
# Ranked Passage IDs: ['7913234', '2347169']
# Similarity Scores: [0.8628282  0.07427204]
#
#
# Query ID: 873914
# Ranked Passage IDs: ['7900108', '6017014']
# Similarity Scores: [0.78455323 0.05931485]
#
#
# Query ID: 874827
# Ranked Passage IDs: ['7947909', '4813563']
# Similarity Scores: [0.65184325 0.25630015]
#
#
# Query ID: 875072
# Ranked Passage IDs: ['7897514', '2862345']
# Similarity Scores: [0.5281761  0.03482826]
#
#
# Query ID: 875113
# Ranked Passage IDs: ['7916270', '6283192']
# Similarity Scores: [ 0.3540441  -0.04938424]
#
#
# Query ID: 87528
# Ranked Passage IDs: ['7889011', '3207188']
# Similarity Scores: [ 0.6813236  -0.00726449]
#
#
# Query ID: 875351
# Ranked Passage IDs: ['7936491', '8826044']
# Similarity Scores: [0.5671471  0.11026184]
#
#
# Query ID: 875391
# Ranked Passage IDs: ['7759120', '2508712']
# Similarity Scores: [0.88739246 0.08051338]
#
#
# Query ID: 875417
# Ranked Passage IDs: ['7977755', '786099']
# Similarity Scores: [0.74961543 0.10644482]
#
#
# Query ID: 87571
# Ranked Passage IDs: ['7308656', '7795645']
# Similarity Scores: [ 0.9429931  -0.02376845]
#
#
# Query ID: 876694
# Ranked Passage IDs: ['7859497', '7911680']
# Similarity Scores: [0.5847283  0.17646861]
#
#
# Query ID: 87708
# Ranked Passage IDs: ['7518715', '7518719', '4483172', '5179077']
# Similarity Scores: [0.80055386 0.7868082  0.17811042 0.06489754]
#
#
# Query ID: 877476
# Ranked Passage IDs: ['7926619', '2614750']
# Similarity Scores: [0.6369776  0.22169422]
#
#
# Query ID: 877684
# Ranked Passage IDs: ['7859835', '1676380']
# Similarity Scores: [0.5935402  0.05259261]
#
#
# Query ID: 877821
# Ranked Passage IDs: ['7775693', '321043']
# Similarity Scores: [ 0.7640333  -0.02169853]
#
#
# Query ID: 87786
# Ranked Passage IDs: ['248402', '1729506', '8191271', '3638224']
# Similarity Scores: [0.81598556 0.7606712  0.14458293 0.00917515]
#
#
# Query ID: 877892
# Ranked Passage IDs: ['7887121', '3561255']
# Similarity Scores: [0.8895719  0.01241817]
#
#
# Query ID: 878363
# Ranked Passage IDs: ['3379369', '5395843']
# Similarity Scores: [ 0.77770746 -0.04840162]
#
#
# Query ID: 878367
# Ranked Passage IDs: ['3371495', '7189501']
# Similarity Scores: [0.7829687  0.02712427]
#
#
# Query ID: 878616
# Ranked Passage IDs: ['7845535', '844102']
# Similarity Scores: [0.5831791  0.17135365]
#
#
# Query ID: 879499
# Ranked Passage IDs: ['7765327', '697583']
# Similarity Scores: [0.73666805 0.09426308]
#
#
# Query ID: 879547
# Ranked Passage IDs: ['7824465', '7824464', '7665949', '492172']
# Similarity Scores: [0.6134068  0.5613145  0.18248996 0.08739248]
#
#
# Query ID: 87998
# Ranked Passage IDs: ['7300858', '4095555']
# Similarity Scores: [0.80584645 0.09469175]
#
#
# Query ID: 880038
# Ranked Passage IDs: ['7721826', '3239744']
# Similarity Scores: [0.7828497  0.16982505]
#
#
# Query ID: 880655
# Ranked Passage IDs: ['7821574', '6488421']
# Similarity Scores: [0.74976397 0.12968147]
#
#
# Query ID: 880751
# Ranked Passage IDs: ['163474', '7086358']
# Similarity Scores: [0.7088378  0.04180306]
#
#
# Query ID: 880780
# Ranked Passage IDs: ['7779743', '2969044']
# Similarity Scores: [0.67746484 0.05507922]
#
#
# Query ID: 881221
# Ranked Passage IDs: ['7812104', '5062055']
# Similarity Scores: [0.5960492  0.03567922]
#
#
# Query ID: 881539
# Ranked Passage IDs: ['7792915', '3328054']
# Similarity Scores: [0.5501944  0.10103343]
#
#
# Query ID: 881603
# Ranked Passage IDs: ['7794571', '557509']
# Similarity Scores: [ 0.69730586 -0.01646362]
#
#
# Query ID: 882606
# Ranked Passage IDs: ['7829257', '7347137']
# Similarity Scores: [0.82708746 0.10520065]
#
#
# Query ID: 882915
# Ranked Passage IDs: ['7744006', '7581333']
# Similarity Scores: [ 0.7511008  -0.07001808]
#
#
# Query ID: 88301
# Ranked Passage IDs: ['7070496', '835621']
# Similarity Scores: [0.8785963  0.06604196]
#
#
# Query ID: 883037
# Ranked Passage IDs: ['7758750', '8665536']
# Similarity Scores: [0.73069644 0.19036654]
#
#
# Query ID: 883205
# Ranked Passage IDs: ['7808561', '1717147']
# Similarity Scores: [0.53060305 0.04238586]
#
#
# Query ID: 883362
# Ranked Passage IDs: ['7973702', '4937499']
# Similarity Scores: [0.8961023  0.15192617]
#
#
# Query ID: 883429
# Ranked Passage IDs: ['7893337', '6443160']
# Similarity Scores: [0.6804371  0.12914881]
#
#
# Query ID: 883660
# Ranked Passage IDs: ['7760402', '1204120']
# Similarity Scores: [0.63684845 0.01241229]
#
#
# Query ID: 883689
# Ranked Passage IDs: ['7848693', '298621']
# Similarity Scores: [ 0.68200725 -0.0066844 ]
#
#
# Query ID: 883832
# Ranked Passage IDs: ['5805910', '5341916']
# Similarity Scores: [0.6713823  0.03773388]
#
#
# Query ID: 884298
# Ranked Passage IDs: ['7928696', '1723364']
# Similarity Scores: [0.54023266 0.07274476]
#
#
# Query ID: 884378
# Ranked Passage IDs: ['7862177', '7180515']
# Similarity Scores: [ 0.78703034 -0.00738196]
#
#
# Query ID: 885081
# Ranked Passage IDs: ['7825420', '4595188']
# Similarity Scores: [0.8453298 0.0396711]
#
#
# Query ID: 885101
# Ranked Passage IDs: ['7922503', '5006915']
# Similarity Scores: [0.81153446 0.2423058 ]
#
#
# Query ID: 88522
# Ranked Passage IDs: ['7668125', '6323344']
# Similarity Scores: [0.5778444 0.0545295]
#
#
# Query ID: 885438
# Ranked Passage IDs: ['3598623', '3414674']
# Similarity Scores: [0.8919747 0.1799451]
#
#
# Query ID: 885539
# Ranked Passage IDs: ['7815448', '5454438']
# Similarity Scores: [0.5880546  0.08712069]
#
#
# Query ID: 886317
# Ranked Passage IDs: ['7907703', '4282089']
# Similarity Scores: [0.7192734  0.21681117]
#
#
# Query ID: 886576
# Ranked Passage IDs: ['7881451', '6423250']
# Similarity Scores: [0.7016356  0.11453152]
#
#
# Query ID: 887506
# Ranked Passage IDs: ['7787364', '5458249']
# Similarity Scores: [0.82230526 0.03908224]
#
#
# Query ID: 887906
# Ranked Passage IDs: ['7729506', '2537243']
# Similarity Scores: [0.707573   0.15033638]
#
#
# Query ID: 888260
# Ranked Passage IDs: ['7934829', '429738']
# Similarity Scores: [0.6702583  0.09262088]
#
#
# Query ID: 888988
# Ranked Passage IDs: ['7823461', '2805851']
# Similarity Scores: [0.68483526 0.07904281]
#
#
# Query ID: 889042
# Ranked Passage IDs: ['7794265', '4678836']
# Similarity Scores: [ 7.1722180e-01 -2.4079972e-04]
#
#
# Query ID: 889107
# Ranked Passage IDs: ['7725956', '4375918']
# Similarity Scores: [0.53568876 0.18147273]
#
#
# Query ID: 890237
# Ranked Passage IDs: ['1813374', '668694']
# Similarity Scores: [0.8650652 0.0769124]
#
#
# Query ID: 890952
# Ranked Passage IDs: ['7785559', '1175979']
# Similarity Scores: [0.50398594 0.07462781]
#
#
# Query ID: 891068
# Ranked Passage IDs: ['7889762', '3461039']
# Similarity Scores: [0.6564218  0.16136989]
#
#
# Query ID: 891444
# ...
# Ranked Passage IDs: ['7283443', '7022569']
# Similarity Scores: [0.85328156 0.08603349]
#
#
# Query ID: 990907
# Ranked Passage IDs: ['7977146', '4622259']
# Similarity Scores: [0.7564403  0.14036013]
#
#
# Query ID: 990951
# Ranked Passage IDs: ['7849940', '5329417']
# Similarity Scores: [0.19631107 0.10526516]
#
#
# Query ID: 991063
# Ranked Passage IDs: ['7283122', '25762']
# Similarity Scores: [0.46983054 0.07306586]
#
#
# Query ID: 991077
# Ranked Passage IDs: ['7283023', '1539049']
# Similarity Scores: [0.74742573 0.06538789]
#
#
# Query ID: 991085
# Ranked Passage IDs: ['7282944', '143992']
# Similarity Scores: [0.757198   0.15798377]
#
#
# Query ID: 991138
# Ranked Passage IDs: ['7748425', '2240311']
# Similarity Scores: [0.765196   0.02586732]
#
#
# Query ID: 991192
# Ranked Passage IDs: ['7282791', '5949692']
# Similarity Scores: [0.89523304 0.10416547]
#
#
# Query ID: 991210
# Ranked Passage IDs: ['7282732', '7727693']
# Similarity Scores: [0.9265794  0.20331194]
#
#
# Query ID: 991301
# Ranked Passage IDs: ['7812041', '6455564']
# Similarity Scores: [0.8957264  0.03179558]
#
#
# Query ID: 991579
# Ranked Passage IDs: ['7823038', '7931314']
# Similarity Scores: [0.70447284 0.09533697]
#
#
# Query ID: 991663
# Ranked Passage IDs: ['7281910', '3870969']
# Similarity Scores: [0.68252957 0.16897173]
#
#
# Query ID: 991682
# Ranked Passage IDs: ['7281827', '5066528']
# Similarity Scores: [0.78512883 0.2506836 ]
#
#
# Query ID: 991694
# Ranked Passage IDs: ['7281732', '8111150']
# Similarity Scores: [0.76724005 0.0441066 ]
#
#
# Query ID: 991723
# Ranked Passage IDs: ['7281667', '6110245']
# Similarity Scores: [ 0.7863465  -0.02571581]
#
#
# Query ID: 991759
# Ranked Passage IDs: ['7281634', '6604903']
# Similarity Scores: [0.7182936  0.14444268]
#
#
# Query ID: 991763
# Ranked Passage IDs: ['7281607', '5846412']
# Similarity Scores: [0.6482758  0.14072633]
#
#
# Query ID: 991788
# Ranked Passage IDs: ['7281514', '7266618']
# Similarity Scores: [0.7865953  0.20434928]
#
#
# Query ID: 991791
# Ranked Passage IDs: ['7281489', '6285647']
# Similarity Scores: [0.8503411 0.109339 ]
#
#
# Query ID: 991855
# Ranked Passage IDs: ['7281314', '7083573']
# Similarity Scores: [0.8320975 0.0612413]
#
#
# Query ID: 991859
# Ranked Passage IDs: ['7832414', '1072919']
# Similarity Scores: [0.91289145 0.0694111 ]
#
#
# Query ID: 991924
# Ranked Passage IDs: ['7281223', '4567227']
# Similarity Scores: [0.83919936 0.09149092]
#
#
# Query ID: 991946
# Ranked Passage IDs: ['7281201', '5452785']
# Similarity Scores: [0.5431531  0.05896652]
#
#
# Query ID: 992096
# Ranked Passage IDs: ['7280888', '5413777']
# Similarity Scores: [0.8351045 0.2316669]
#
#
# Query ID: 992102
# Ranked Passage IDs: ['7280867', '8461274']
# Similarity Scores: [0.7443261  0.00977234]
#
#
# Query ID: 99211
# Ranked Passage IDs: ['310998', '4724687']
# Similarity Scores: [ 0.80339783 -0.05946996]
#
#
# Query ID: 992110
# Ranked Passage IDs: ['2604603', '8624780']
# Similarity Scores: [0.92395693 0.10692845]
#
#
# Query ID: 992246
# Ranked Passage IDs: ['7934611', '878780']
# Similarity Scores: [0.875758   0.01643773]
#
#
# Query ID: 992249
# Ranked Passage IDs: ['7280431', '1636213']
# Similarity Scores: [0.44056684 0.07815048]
#
#
# Query ID: 992260
# Ranked Passage IDs: ['7911629', '2936149']
# Similarity Scores: [0.90262496 0.25591162]
#
#
# Query ID: 992349
# Ranked Passage IDs: ['7765911', '6129512']
# Similarity Scores: [0.84137857 0.15781076]
#
#
# Query ID: 992362
# Ranked Passage IDs: ['7280098', '3296453']
# Similarity Scores: [0.59308416 0.04856866]
#
#
# Query ID: 992407
# Ranked Passage IDs: ['7279808', '998210']
# Similarity Scores: [0.76858515 0.10539705]
#
#
# Query ID: 992535
# Ranked Passage IDs: ['7279523', '6696086']
# Similarity Scores: [0.5553705  0.18499434]
#
#
# Query ID: 992546
# Ranked Passage IDs: ['4072084', '3458499']
# Similarity Scores: [ 0.80592346 -0.08052728]
#
#
# Query ID: 992629
# Ranked Passage IDs: ['7757326', '3660898']
# Similarity Scores: [ 0.8714859  -0.01005534]
#
#
# Query ID: 992846
# Ranked Passage IDs: ['7278869', '5648123']
# Similarity Scores: [0.67193455 0.0349488 ]
#
#
# Query ID: 992897
# Ranked Passage IDs: ['7732878', '6057340']
# Similarity Scores: [0.8462233  0.16205242]
#
#
# Query ID: 992949
# Ranked Passage IDs: ['7278560', '6535996']
# Similarity Scores: [ 0.8621836  -0.04115037]
#
#
# Query ID: 993026
# Ranked Passage IDs: ['7278248', '4223839']
# Similarity Scores: [0.6100644  0.10671759]
#
#
# Query ID: 993061
# Ranked Passage IDs: ['7278147', '6270287']
# Similarity Scores: [ 0.52958506 -0.09192143]
#
#
# Query ID: 993413
# Ranked Passage IDs: ['588288', '6817782']
# Similarity Scores: [0.743382   0.09516926]
#
#
# Query ID: 993454
# Ranked Passage IDs: ['5508484', '7512880']
# Similarity Scores: [0.7607254  0.10276046]
#
#
# Query ID: 993474
# Ranked Passage IDs: ['7277568', '2703481']
# Similarity Scores: [0.87383765 0.23913167]
#
#
# Query ID: 993478
# Ranked Passage IDs: ['7277532', '4665812']
# Similarity Scores: [0.8449655  0.04857647]
#
#
# Query ID: 993481
# Ranked Passage IDs: ['7475821', '1965397']
# Similarity Scores: [0.74412596 0.21103016]
#
#
# Query ID: 993601
# Ranked Passage IDs: ['7900040', '6853022']
# Similarity Scores: [0.85259736 0.09798831]
#
#
# Query ID: 993606
# Ranked Passage IDs: ['7277219', '1264107']
# Similarity Scores: [0.85562134 0.16156545]
#
#
# Query ID: 993734
# Ranked Passage IDs: ['2331927', '3954429']
# Similarity Scores: [ 0.8615247  -0.00997896]
#
#
# Query ID: 993812
# Ranked Passage IDs: ['7730067', '318907']
# Similarity Scores: [0.8739446  0.07580397]
#
#
# Query ID: 993849
# Ranked Passage IDs: ['7931826', '7756015']
# Similarity Scores: [0.79565847 0.0808856 ]
#
#
# Query ID: 993908
# Ranked Passage IDs: ['7276586', '4520079']
# Similarity Scores: [0.6977137 0.029109 ]
#
#
# Query ID: 993959
# Ranked Passage IDs: ['7276385', '2190940']
# Similarity Scores: [0.7178057  0.04003431]
#
#
# Query ID: 993986
# Ranked Passage IDs: ['7276268', '2965800']
# Similarity Scores: [0.8672051  0.15834855]
#
#
# Query ID: 994026
# Ranked Passage IDs: ['7276062', '8725224']
# Similarity Scores: [0.775271   0.15882884]
#
#
# Query ID: 994088
# Ranked Passage IDs: ['7275838', '8381416']
# Similarity Scores: [0.8314223  0.09051768]
#
#
# Query ID: 994119
# Ranked Passage IDs: ['7275759', '3560472']
# Similarity Scores: [ 0.5580043  -0.00288844]
#
#
# Query ID: 994219
# Ranked Passage IDs: ['7782250', '4198754']
# Similarity Scores: [0.64702797 0.09683265]
#
#
# Query ID: 994228
# Ranked Passage IDs: ['7275543', '5630539']
# Similarity Scores: [0.7208383  0.08619852]
#
#
# Query ID: 994240
# Ranked Passage IDs: ['7852655', '7079854']
# Similarity Scores: [0.8078194  0.10922762]
#
#
# Query ID: 994343
# Ranked Passage IDs: ['7275360', '6016090']
# Similarity Scores: [0.74800974 0.04050914]
#
#
# Query ID: 994447
# Ranked Passage IDs: ['2555130', '6111452']
# Similarity Scores: [0.8710797 0.1933309]
#
#
# Query ID: 994458
# Ranked Passage IDs: ['7275147', '3659988']
# Similarity Scores: [0.70795274 0.00698953]
#
#
# Query ID: 994523
# Ranked Passage IDs: ['7275009', '1878548']
# Similarity Scores: [0.7156653  0.14395979]
#
#
# Query ID: 994710
# Ranked Passage IDs: ['7274753', '7870858']
# Similarity Scores: [0.81373274 0.03533503]
#
#
# Query ID: 994962
# Ranked Passage IDs: ['5008353', '3502939']
# Similarity Scores: [0.54742855 0.11227733]
#
#
# Query ID: 994964
# Ranked Passage IDs: ['7274419', '6452504']
# Similarity Scores: [0.7537053 0.077896 ]
#
#
# Query ID: 995141
# Ranked Passage IDs: ['7274238', '6091571']
# Similarity Scores: [0.62829256 0.12049576]
#
#
# Query ID: 995188
# Ranked Passage IDs: ['7274184', '6058047']
# Similarity Scores: [0.89195275 0.06299079]
#
#
# Query ID: 995190
# Ranked Passage IDs: ['7274163', '8579726']
# Similarity Scores: [0.40289474 0.10478207]
#
#
# Query ID: 995232
# Ranked Passage IDs: ['7274086', '5764638']
# Similarity Scores: [0.56860745 0.0202086 ]
#
#
# Query ID: 995259
# Ranked Passage IDs: ['7858903', '4517084']
# Similarity Scores: [ 0.81299484 -0.01784015]
#
#
# Query ID: 995263
# Ranked Passage IDs: ['7274047', '4278214']
# Similarity Scores: [0.83647996 0.2055458 ]
#
#
# Query ID: 995382
# Ranked Passage IDs: ['7273880', '6190215']
# Similarity Scores: [0.86766523 0.10651644]
#
#
# Query ID: 995443
# Ranked Passage IDs: ['6818442', '1572322']
# Similarity Scores: [0.89024115 0.19479263]
#
#
# Query ID: 995532
# Ranked Passage IDs: ['7273720', '8639008']
# Similarity Scores: [0.8021408  0.07478997]
#
#
# Query ID: 995546
# Ranked Passage IDs: ['7273647', '4286757']
# Similarity Scores: [0.7391512 0.1199521]
#
#
# Query ID: 995633
# Ranked Passage IDs: ['7273484', '4466216']
# Similarity Scores: [ 0.73041344 -0.06586406]
#
#
# Query ID: 995753
# Ranked Passage IDs: ['7273358', '7697848']
# Similarity Scores: [0.80244905 0.07318607]
#
#
# Query ID: 995754
# Ranked Passage IDs: ['7273343', '5377945']
# Similarity Scores: [0.8361174 0.2979775]
#
#
# Query ID: 995756
# Ranked Passage IDs: ['1602468', '4960146']
# Similarity Scores: [0.91119665 0.22095035]
#
#
# Query ID: 995763
# Ranked Passage IDs: ['7273271', '1905010']
# Similarity Scores: [0.9209384  0.00835916]
#
#
# Query ID: 996024
# Ranked Passage IDs: ['7771248', '2998555']
# Similarity Scores: [0.6973906 0.1252893]
#
#
# Query ID: 996058
# Ranked Passage IDs: ['7272717', '3469260']
# Similarity Scores: [ 0.91452754 -0.08787642]
#
#
# Query ID: 996117
# Ranked Passage IDs: ['7272456', '6414620']
# Similarity Scores: [0.8002389  0.15092485]
#
#
# Query ID: 996246
# Ranked Passage IDs: ['7272184', '454152']
# Similarity Scores: [0.55172247 0.07905234]
#
#
# Query ID: 996252
# Ranked Passage IDs: ['7854738', '1272727']
# Similarity Scores: [0.69116896 0.13407274]
#
#
# Query ID: 996413
# Ranked Passage IDs: ['7272020', '6120226']
# Similarity Scores: [0.8593503  0.02627844]
#
#
# Query ID: 996422
# Ranked Passage IDs: ['3960785', '5963591']
# Similarity Scores: [0.86188185 0.03393602]
#
#
# Query ID: 996501
# Ranked Passage IDs: ['7271870', '968007']
# Similarity Scores: [0.7658381  0.16458075]
#
#
# Query ID: 996562
# Ranked Passage IDs: ['7271746', '4606080']
# Similarity Scores: [0.6102472  0.16133222]
#
#
# Query ID: 996627
# Ranked Passage IDs: ['7271540', '3504154']
# Similarity Scores: [0.7054004  0.08358105]
#
#
# Query ID: 996628
# Ranked Passage IDs: ['7271525', '2946986']
# Similarity Scores: [0.7635716  0.06649266]
#
#
# Query ID: 996687
# Ranked Passage IDs: ['7271437', '8110291']
# Similarity Scores: [0.7294614  0.17342612]
#
#
# Query ID: 996743
# Ranked Passage IDs: ['7271337', '7040579']
# Similarity Scores: [0.72885835 0.1378691 ]
#
#
# Query ID: 99676
# Ranked Passage IDs: ['7311518', '1177543']
# Similarity Scores: [0.6816955  0.13532811]
#
#
# Query ID: 996815
# Ranked Passage IDs: ['7271244', '1263711']
# Similarity Scores: [0.89796716 0.05007065]
#
#
# Query ID: 996831
# Ranked Passage IDs: ['7271127', '3889008']
# Similarity Scores: [0.2926489  0.22020707]
#
#
# Query ID: 996879
# Ranked Passage IDs: ['7271010', '8298261']
# Similarity Scores: [0.916217   0.08018668]
#
#
# Query ID: 996891
# Ranked Passage IDs: ['7270991', '4048362']
# Similarity Scores: [0.8859727  0.15390038]
#
#
# Query ID: 996934
# Ranked Passage IDs: ['7270929', '2648698']
# Similarity Scores: [0.85019726 0.02347687]
#
#
# Query ID: 996957
# Ranked Passage IDs: ['7884111', '8488499']
# Similarity Scores: [0.6430377  0.07393955]
#
#
# Query ID: 997166
# Ranked Passage IDs: ['7270447', '4718376']
# Similarity Scores: [0.8307921 0.0423418]
#
#
# Query ID: 997183
# Ranked Passage IDs: ['7270398', '8352022']
# Similarity Scores: [0.76415294 0.1066944 ]
#
#
# Query ID: 997221
# Ranked Passage IDs: ['7917722', '646367']
# Similarity Scores: [0.9044768  0.05538314]
#
#
# Query ID: 997227
# Ranked Passage IDs: ['7270352', '3675165']
# Similarity Scores: [0.7336422  0.01150223]
#
#
# Query ID: 997281
# Ranked Passage IDs: ['600320', '5787406']
# Similarity Scores: [ 0.91703016 -0.00321503]
#
#
# Query ID: 997389
# Ranked Passage IDs: ['7270214', '4415092']
# Similarity Scores: [0.91584873 0.18325536]
#
#
# Query ID: 997422
# Ranked Passage IDs: ['7835634', '5423821']
# Similarity Scores: [0.56648725 0.2160778 ]
#
#
# Query ID: 997641
# Ranked Passage IDs: ['7966116', '1599399']
# Similarity Scores: [0.8469159  0.06169853]
#
#
# Query ID: 997678
# Ranked Passage IDs: ['7269594', '6388952']
# Similarity Scores: [0.9507933  0.07041194]
#
#
# Query ID: 997782
# Ranked Passage IDs: ['7269335', '5959962']
# Similarity Scores: [ 0.8968155  -0.02224964]
#
#
# Query ID: 997796
# Ranked Passage IDs: ['7269247', '8006818']
# Similarity Scores: [0.7820994  0.04545596]
#
#
# Query ID: 997841
# Ranked Passage IDs: ['7269128', '3868425']
# Similarity Scores: [0.8810207  0.10468607]
#
#
# Query ID: 997899
# Ranked Passage IDs: ['7773345', '730211']
# Similarity Scores: [0.8318085  0.15018053]
#
#
# Query ID: 997934
# Ranked Passage IDs: ['7268878', '8514356']
# Similarity Scores: [0.8593476  0.09429882]
#
#
# Query ID: 997959
# Ranked Passage IDs: ['7268833', '2503036']
# Similarity Scores: [0.59306717 0.09818091]
#
#
# Query ID: 998020
# Ranked Passage IDs: ['7268664', '6572700']
# Similarity Scores: [0.7369554  0.18473373]
#
#
# Query ID: 998027
# Ranked Passage IDs: ['7268624', '7196166']
# Similarity Scores: [ 0.7094905  -0.04658066]
#
#
# Query ID: 998096
# Ranked Passage IDs: ['7788554', '2991958']
# Similarity Scores: [0.93050617 0.15862547]
#
#
# Query ID: 998171
# Ranked Passage IDs: ['7883105', '4987321']
# Similarity Scores: [0.8559453 0.0723425]
#
#
# Query ID: 998174
# Ranked Passage IDs: ['7268439', '6276341']
# Similarity Scores: [0.7483637  0.04403185]
#
#
# Query ID: 998235
# Ranked Passage IDs: ['2691931', '2870511']
# Similarity Scores: [0.78926253 0.06382518]
#
#
# Query ID: 998507
# Ranked Passage IDs: ['7817835', '748016']
# Similarity Scores: [0.7929121  0.15681252]
#
#
# Query ID: 998510
# Ranked Passage IDs: ['7267927', '8135589']
# Similarity Scores: [0.7497708  0.20529284]
#
#
# Query ID: 998563
# Ranked Passage IDs: ['7928512', '6602991']
# Similarity Scores: [ 0.80086946 -0.02319856]
#
#
# Query ID: 998614
# Ranked Passage IDs: ['7267686', '3901179']
# Similarity Scores: [0.9391474  0.22586496]
#
#
# Query ID: 998620
# Ranked Passage IDs: ['4716537', '1510930']
# Similarity Scores: [0.8892129  0.02676132]
#
#
# Query ID: 998650
# Ranked Passage IDs: ['7898170', '2237808']
# Similarity Scores: [0.8107009 0.1816045]
#
#
# Query ID: 998684
# Ranked Passage IDs: ['7267428', '6036897']
# Similarity Scores: [ 0.8116431  -0.07209203]
#
#
# Query ID: 998742
# Ranked Passage IDs: ['7968247', '903679']
# Similarity Scores: [0.71680325 0.00403594]
#
#
# Query ID: 998860
# Ranked Passage IDs: ['7267073', '1198927']
# Similarity Scores: [ 0.6623163  -0.04743014]
#
#
# Query ID: 998875
# Ranked Passage IDs: ['7267013', '2054402']
# Similarity Scores: [0.53439075 0.14715433]
#
#
# Query ID: 998902
# Ranked Passage IDs: ['7266855', '471372']
# Similarity Scores: [0.6128184  0.03925319]
#
#
# Query ID: 999021
# Ranked Passage IDs: ['7266499', '3762473']
# Similarity Scores: [0.81424516 0.08087169]
#
#
# Query ID: 999070
# Ranked Passage IDs: ['7266336', '7555310']
# Similarity Scores: [0.8756801  0.06034016]
#
#
# Query ID: 999079
# Ranked Passage IDs: ['7266253', '7230898']
# Similarity Scores: [0.87740463 0.10548125]
#
#
# Query ID: 999110
# Ranked Passage IDs: ['7266132', '5850405']
# Similarity Scores: [0.87713933 0.02151106]
#
#
# Query ID: 999133
# Ranked Passage IDs: ['7266069', '5635525']
# Similarity Scores: [0.7970904  0.02684421]
#
#
# Query ID: 999272
# Ranked Passage IDs: ['7853948', '8655078']
# Similarity Scores: [0.8284431  0.04755134]
#
#
# Query ID: 999393
# Ranked Passage IDs: ['7265556', '5022839']
# Similarity Scores: [0.8042859  0.13812418]
#
#
# Query ID: 999450
# Ranked Passage IDs: ['7265427', '6559166']
# Similarity Scores: [0.88605565 0.03682722]
#
#
# Query ID: 999520
# Ranked Passage IDs: ['7265251', '6338119']
# Similarity Scores: [0.79317826 0.04383933]
#
#
# Query ID: 999565
# Ranked Passage IDs: ['7265121', '2393599']
# Similarity Scores: [0.90330917 0.05977866]
#
#
# Query ID: 999603
# Ranked Passage IDs: ['7265024', '6486449']
# Similarity Scores: [0.62394327 0.09061409]
#
#
# Query ID: 999691
# Ranked Passage IDs: ['7264912', '6382139']
# Similarity Scores: [0.90125877 0.21194696]
#
#
# Query ID: 999791
# Ranked Passage IDs: ['7264701', '2895425']
# Similarity Scores: [0.856673   0.15324152]
#
#
# Query ID: 999800
# Ranked Passage IDs: ['7264655', '7144318']
# Similarity Scores: [ 0.880883   -0.01022386]
#
#
# Query ID: 999815
# Ranked Passage IDs: ['7264612', '8563224']
# Similarity Scores: [ 0.8893382  -0.04347342]
#
#
# Query ID: 999828
# Ranked Passage IDs: ['7904572', '1012593']
# Similarity Scores: [0.749845   0.08523943]
#
#
# Query ID: 99985
# Ranked Passage IDs: ['7983007', '1696520']
# Similarity Scores: [0.8248416  0.20937175]
#
#
# Query ID: 999858
# Ranked Passage IDs: ['7264543', '1249935']
# Similarity Scores: [0.80981493 0.07949363]
#
#
# Mean Reciprocal Rank (MRR) across queries: 0.9998993761320185

# %%
import pandas as pd

# Define the evaluation metrics dictionary
metrics = {
    'test-eval_cosine_accuracy': 0.9865,
    'test-eval_cosine_accuracy_threshold': 0.5036637783050537,
    'test-eval_cosine_f1': 0.9865013498650135,
    'test-eval_cosine_f1_threshold': 0.47773101925849915,
    'test-eval_cosine_precision': 0.9864027194561088,
    'test-eval_cosine_recall': 0.9866,
    'test-eval_cosine_ap': 0.9990008667480205,
    'test-eval_cosine_mcc': 0.9730000194600006
}

# Convert dictionary to a DataFrame
df = pd.DataFrame(list(metrics.items()), columns=["Metric", "Value"])

# Display the table
df
# Out:
#                                 Metric     Value
# 0            test-eval_cosine_accuracy  0.986500
# 1  test-eval_cosine_accuracy_threshold  0.503664
# 2                  test-eval_cosine_f1  0.986501
# 3        test-eval_cosine_f1_threshold  0.477731
# 4           test-eval_cosine_precision  0.986403
# 5              test-eval_cosine_recall  0.986600
# 6                  test-eval_cosine_ap  0.999001
# 7                 test-eval_cosine_mcc  0.973000

# %%
import json
import pandas as pd

# Example JSON data as a string (you could also load this from a file)
data_json = """
{
  "query_ndcg": {
    "1": {
      "BM25 baseline": 0.9702678299923723,
      "Basic LSI with k=150 dimensions": 0.9758521455086463,
      "Field-weighted LSI": 0.9848920829832359,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9830304948282328
    },
    "2": {
      "BM25 baseline": 0.9676702855814429,
      "Basic LSI with k=150 dimensions": 0.9629813342264886,
      "Field-weighted LSI": 0.9667761720787513,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9794256057551403
    },
    "3": {
      "BM25 baseline": 0.9044563947524946,
      "Basic LSI with k=150 dimensions": 0.9933589454400779,
      "Field-weighted LSI": 0.9898865373853496,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9881020176053733
    },
    "4": {
      "BM25 baseline": 0.9581091124245024,
      "Basic LSI with k=150 dimensions": 0.948554309956447,
      "Field-weighted LSI": 0.9960109913990778,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9878911924184829
    },
    "5": {
      "BM25 baseline": 0.9658615078539107,
      "Basic LSI with k=150 dimensions": 0.9575689562960752,
      "Field-weighted LSI": 0.9505284770054349,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9655739770289112
    },
    "6": {
      "BM25 baseline": 0.9752052508426301,
      "Basic LSI with k=150 dimensions": 0.9627981168426469,
      "Field-weighted LSI": 0.9581046966570809,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9591202408479728
    },
    "7": {
      "BM25 baseline": 0.9818993385732202,
      "Basic LSI with k=150 dimensions": 0.9807871865261831,
      "Field-weighted LSI": 0.9809150399185756,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9823527299043489
    },
    "8": {
      "BM25 baseline": 0.9321327160076697,
      "Basic LSI with k=150 dimensions": 0.9710645286552664,
      "Field-weighted LSI": 0.9762610082520967,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9754601319164254
    },
    "9": {
      "BM25 baseline": 0.9245261750389756,
      "Basic LSI with k=150 dimensions": 0.9676601688646809,
      "Field-weighted LSI": 0.9667775455963419,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9776080183622335
    },
    "10": {
      "BM25 baseline": 0.9529765131303531,
      "Basic LSI with k=150 dimensions": 0.9645555969472415,
      "Field-weighted LSI": 0.9691697980787715,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9621459956970113
    },
    "11": {
      "BM25 baseline": 0.8964577324065195,
      "Basic LSI with k=150 dimensions": 0.9609562747330634,
      "Field-weighted LSI": 0.9807828639897396,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9793535110310084
    },
    "12": {
      "BM25 baseline": 0.984695848675374,
      "Basic LSI with k=150 dimensions": 0.9788847916645828,
      "Field-weighted LSI": 0.9693232588401846,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9857402370727113
    },
    "13": {
      "BM25 baseline": 0.9782201890488277,
      "Basic LSI with k=150 dimensions": 0.9855064285891632,
      "Field-weighted LSI": 0.9902678789460896,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9887766464301465
    },
    "14": {
      "BM25 baseline": 0.970356466152375,
      "Basic LSI with k=150 dimensions": 0.9628576588661965,
      "Field-weighted LSI": 0.9280259962459354,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9809106119256944
    },
    "15": {
      "BM25 baseline": 0.9835913643588563,
      "Basic LSI with k=150 dimensions": 0.9690110565535949,
      "Field-weighted LSI": 0.9027999093185158,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9030498209383528
    },
    "16": {
      "BM25 baseline": 0.9966040770726391,
      "Basic LSI with k=150 dimensions": 0.9855664146422799,
      "Field-weighted LSI": 0.994992385847428,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9942910776627677
    },
    "17": {
      "BM25 baseline": 0.9825657033733907,
      "Basic LSI with k=150 dimensions": 0.9827942717636607,
      "Field-weighted LSI": 0.8947880226442804,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9809054561880343
    },
    "18": {
      "BM25 baseline": 0.9621443885246534,
      "Basic LSI with k=150 dimensions": 0.9441357282937284,
      "Field-weighted LSI": 0.9594627248767399,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9832791715266921
    },
    "19": {
      "BM25 baseline": 0.9334185635964451,
      "Basic LSI with k=150 dimensions": 0.9829274742442599,
      "Field-weighted LSI": 0.9933716770959169,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9847174929495353
    },
    "20": {
      "BM25 baseline": 0.9516312021336671,
      "Basic LSI with k=150 dimensions": 0.9796666282990453,
      "Field-weighted LSI": 0.9786787250738833,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9556153266519222
    },
    "21": {
      "BM25 baseline": 0.9578392479069989,
      "Basic LSI with k=150 dimensions": 0.9766666646329698,
      "Field-weighted LSI": 0.9758102199492783,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9850558651966211
    },
    "22": {
      "BM25 baseline": 0.9748673310883267,
      "Basic LSI with k=150 dimensions": 0.9918139964433209,
      "Field-weighted LSI": 0.9873837905369207,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9883659434195166
    },
    "23": {
      "BM25 baseline": 0.9018046783186535,
      "Basic LSI with k=150 dimensions": 0.9741947524048282,
      "Field-weighted LSI": 0.9574728776175179,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9573189253711919
    },
    "24": {
      "BM25 baseline": 0.9261770173775742,
      "Basic LSI with k=150 dimensions": 0.9739773208175877,
      "Field-weighted LSI": 0.9941760144154915,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9866652960369205
    },
    "25": {
      "BM25 baseline": 0.9514747319710257,
      "Basic LSI with k=150 dimensions": 0.9493207798604006,
      "Field-weighted LSI": 0.9288759835628523,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9038360948563292
    },
    "26": {
      "BM25 baseline": 0.9699219676915909,
      "Basic LSI with k=150 dimensions": 0.9609181526850149,
      "Field-weighted LSI": 0.9203767389876794,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9689337600130596
    },
    "27": {
      "BM25 baseline": 0.9655588343889085,
      "Basic LSI with k=150 dimensions": 0.9249466577802449,
      "Field-weighted LSI": 0.9275834806993435,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9140204740001455
    },
    "28": {
      "BM25 baseline": 0.9657423422096584,
      "Basic LSI with k=150 dimensions": 0.9836744745815332,
      "Field-weighted LSI": 0.9854102537186108,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9854102537186108
    },
    "29": {
      "BM25 baseline": 0.9925132360531861,
      "Basic LSI with k=150 dimensions": 0.986803734351502,
      "Field-weighted LSI": 0.9915805450761829,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9840163312121945
    },
    "30": {
      "BM25 baseline": 0.965399565159306,
      "Basic LSI with k=150 dimensions": 0.9437529122758956,
      "Field-weighted LSI": 0.9827509727452103,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9774730536666356
    }
  },
  "system_averages": {
    "BM25 baseline": 0.9581363203901849,
    "Basic LSI with k=150 dimensions": 0.9694519154248875,
    "Field-weighted LSI": 0.966107888984751,
    "Field-weighted LSI with BERT-enhanced indexing": 0.9716148584744075
  },
  "overall_comparison": [
    {
      "system": "Field-weighted LSI with BERT-enhanced indexing",
      "average_ndcg@10": 0.9716148584744075
    },
    {
      "system": "Basic LSI with k=150 dimensions",
      "average_ndcg@10": 0.9694519154248875
    },
    {
      "system": "Field-weighted LSI",
      "average_ndcg@10": 0.966107888984751
    },
    {
      "system": "BM25 baseline",
      "average_ndcg@10": 0.9581363203901849
    }
  ]
}
"""

# Parse JSON data
data = json.loads(data_json)

# Extract the query_ndcg dictionary
query_ndcg = data["query_ndcg"]

# Initialize a dictionary to accumulate scores per system
system_scores = {}

# Loop over each query in query_ndcg (keys are query numbers as strings)
for query_num, systems in query_ndcg.items():
    for system, ndcg in systems.items():
        system_scores.setdefault(system, []).append(ndcg)

# Compute the average NDCG for each system across all queries
average_ndcg = {system: sum(scores) / len(scores) for system, scores in system_scores.items()}

# Convert the averages into a DataFrame for easy viewing
df_avg_ndcg = pd.DataFrame(list(average_ndcg.items()), columns=["System", "Average NDCG@10"])
df_avg_ndcg = df_avg_ndcg.sort_values("Average NDCG@10", ascending=False).reset_index(drop=True)
print(df_avg_ndcg.to_string(index=False))

# Interpretation:
print("\nInterpretation:")
print("NDCG (Normalized Discounted Cumulative Gain) is a ranking metric that evaluates")
print("how well the system orders the documents; values closer to 1 indicate near-ideal ranking.")
print("The computed average NDCG@10 for each system are:")
for system, avg in average_ndcg.items():
    print(f"  - {system}: {avg:.4f}")
print("\nOverall, Field-weighted LSI with BERT-enhanced indexing shows the highest average NDCG@10,")
print("indicating it ranks results most closely to the ideal across the evaluated queries.")
# Out:
#                                         System  Average NDCG@10
# Field-weighted LSI with BERT-enhanced indexing         0.971615
#                Basic LSI with k=150 dimensions         0.969452
#                             Field-weighted LSI         0.966108
#                                  BM25 baseline         0.958136
#
# Interpretation:
# NDCG (Normalized Discounted Cumulative Gain) is a ranking metric that evaluates
# how well the system orders the documents; values closer to 1 indicate near-ideal ranking.
# The computed average NDCG@10 for each system are:
#   - BM25 baseline: 0.9581
#   - Basic LSI with k=150 dimensions: 0.9695
#   - Field-weighted LSI: 0.9661
#   - Field-weighted LSI with BERT-enhanced indexing: 0.9716
#
# Overall, Field-weighted LSI with BERT-enhanced indexing shows the highest average NDCG@10,
# indicating it ranks results most closely to the ideal across the evaluated queries.

# %%
import pandas as pd

# Create a list of dictionaries with the data
data = [
    {
        "system": "Field-weighted LSI with BERT-enhanced indexing",
        "average_ndcg@10": 0.9716148584744075
    },
    {
        "system": "Basic LSI with k=150 dimensions",
        "average_ndcg@10": 0.9694519154248875
    },
    {
        "system": "Field-weighted LSI",
        "average_ndcg@10": 0.966107888984751
    },
    {
        "system": "BM25 baseline",
        "average_ndcg@10": 0.9581363203901849
    }
]

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
#                                            system  average_ndcg@10
# 0  Field-weighted LSI with BERT-enhanced indexing         0.971615
# 1                 Basic LSI with k=150 dimensions         0.969452
# 2                              Field-weighted LSI         0.966108
# 3                                   BM25 baseline         0.958136

# %%
import json
import pandas as pd
import numpy as np

# Sample JSON data (replace this multi-line string with your actual JSON data if reading from a file)
data_json = """
{
  "query_ndcg": {
    "1": {
      "BM25 baseline": 0.9702678299923723,
      "Basic LSI with k=150 dimensions": 0.9758521455086463,
      "Field-weighted LSI": 0.9848920829832359,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9830304948282328
    },
    "2": {
      "BM25 baseline": 0.9676702855814429,
      "Basic LSI with k=150 dimensions": 0.9629813342264886,
      "Field-weighted LSI": 0.9667761720787513,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9794256057551403
    },
    "3": {
      "BM25 baseline": 0.9044563947524946,
      "Basic LSI with k=150 dimensions": 0.9933589454400779,
      "Field-weighted LSI": 0.9898865373853496,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9881020176053733
    },
    "4": {
      "BM25 baseline": 0.9581091124245024,
      "Basic LSI with k=150 dimensions": 0.948554309956447,
      "Field-weighted LSI": 0.9960109913990778,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9878911924184829
    },
    "5": {
      "BM25 baseline": 0.9658615078539107,
      "Basic LSI with k=150 dimensions": 0.9575689562960752,
      "Field-weighted LSI": 0.9505284770054349,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9655739770289112
    },
    "6": {
      "BM25 baseline": 0.9752052508426301,
      "Basic LSI with k=150 dimensions": 0.9627981168426469,
      "Field-weighted LSI": 0.9581046966570809,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9591202408479728
    },
    "7": {
      "BM25 baseline": 0.9818993385732202,
      "Basic LSI with k=150 dimensions": 0.9807871865261831,
      "Field-weighted LSI": 0.9809150399185756,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9823527299043489
    },
    "8": {
      "BM25 baseline": 0.9321327160076697,
      "Basic LSI with k=150 dimensions": 0.9710645286552664,
      "Field-weighted LSI": 0.9762610082520967,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9754601319164254
    },
    "9": {
      "BM25 baseline": 0.9245261750389756,
      "Basic LSI with k=150 dimensions": 0.9676601688646809,
      "Field-weighted LSI": 0.9667775455963419,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9776080183622335
    },
    "10": {
      "BM25 baseline": 0.9529765131303531,
      "Basic LSI with k=150 dimensions": 0.9645555969472415,
      "Field-weighted LSI": 0.9691697980787715,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9621459956970113
    },
    "11": {
      "BM25 baseline": 0.8964577324065195,
      "Basic LSI with k=150 dimensions": 0.9609562747330634,
      "Field-weighted LSI": 0.9807828639897396,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9793535110310084
    },
    "12": {
      "BM25 baseline": 0.984695848675374,
      "Basic LSI with k=150 dimensions": 0.9788847916645828,
      "Field-weighted LSI": 0.9693232588401846,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9857402370727113
    },
    "13": {
      "BM25 baseline": 0.9782201890488277,
      "Basic LSI with k=150 dimensions": 0.9855064285891632,
      "Field-weighted LSI": 0.9902678789460896,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9887766464301465
    },
    "14": {
      "BM25 baseline": 0.970356466152375,
      "Basic LSI with k=150 dimensions": 0.9628576588661965,
      "Field-weighted LSI": 0.9280259962459354,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9809106119256944
    },
    "15": {
      "BM25 baseline": 0.9835913643588563,
      "Basic LSI with k=150 dimensions": 0.9690110565535949,
      "Field-weighted LSI": 0.9027999093185158,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9030498209383528
    },
    "16": {
      "BM25 baseline": 0.9966040770726391,
      "Basic LSI with k=150 dimensions": 0.9855664146422799,
      "Field-weighted LSI": 0.994992385847428,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9942910776627677
    },
    "17": {
      "BM25 baseline": 0.9825657033733907,
      "Basic LSI with k=150 dimensions": 0.9827942717636607,
      "Field-weighted LSI": 0.8947880226442804,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9809054561880343
    },
    "18": {
      "BM25 baseline": 0.9621443885246534,
      "Basic LSI with k=150 dimensions": 0.9441357282937284,
      "Field-weighted LSI": 0.9594627248767399,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9832791715266921
    },
    "19": {
      "BM25 baseline": 0.9334185635964451,
      "Basic LSI with k=150 dimensions": 0.9829274742442599,
      "Field-weighted LSI": 0.9933716770959169,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9847174929495353
    },
    "20": {
      "BM25 baseline": 0.9516312021336671,
      "Basic LSI with k=150 dimensions": 0.9796666282990453,
      "Field-weighted LSI": 0.9786787250738833,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9556153266519222
    },
    "21": {
      "BM25 baseline": 0.9578392479069989,
      "Basic LSI with k=150 dimensions": 0.9766666646329698,
      "Field-weighted LSI": 0.9758102199492783,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9850558651966211
    },
    "22": {
      "BM25 baseline": 0.9748673310883267,
      "Basic LSI with k=150 dimensions": 0.9918139964433209,
      "Field-weighted LSI": 0.9873837905369207,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9883659434195166
    },
    "23": {
      "BM25 baseline": 0.9018046783186535,
      "Basic LSI with k=150 dimensions": 0.9741947524048282,
      "Field-weighted LSI": 0.9574728776175179,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9573189253711919
    },
    "24": {
      "BM25 baseline": 0.9261770173775742,
      "Basic LSI with k=150 dimensions": 0.9739773208175877,
      "Field-weighted LSI": 0.9941760144154915,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9866652960369205
    },
    "25": {
      "BM25 baseline": 0.9514747319710257,
      "Basic LSI with k=150 dimensions": 0.9493207798604006,
      "Field-weighted LSI": 0.9288759835628523,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9038360948563292
    },
    "26": {
      "BM25 baseline": 0.9699219676915909,
      "Basic LSI with k=150 dimensions": 0.9609181526850149,
      "Field-weighted LSI": 0.9203767389876794,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9689337600130596
    },
    "27": {
      "BM25 baseline": 0.9655588343889085,
      "Basic LSI with k=150 dimensions": 0.9249466577802449,
      "Field-weighted LSI": 0.9275834806993435,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9140204740001455
    },
    "28": {
      "BM25 baseline": 0.9657423422096584,
      "Basic LSI with k=150 dimensions": 0.9836744745815332,
      "Field-weighted LSI": 0.9854102537186108,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9854102537186108
    },
    "29": {
      "BM25 baseline": 0.9925132360531861,
      "Basic LSI with k=150 dimensions": 0.986803734351502,
      "Field-weighted LSI": 0.9915805450761829,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9840163312121945
    },
    "30": {
      "BM25 baseline": 0.965399565159306,
      "Basic LSI with k=150 dimensions": 0.9437529122758956,
      "Field-weighted LSI": 0.9827509727452103,
      "Field-weighted LSI with BERT-enhanced indexing": 0.9774730536666356
    }
  },
  "system_averages": {
    "BM25 baseline": 0.9581363203901849,
    "Basic LSI with k=150 dimensions": 0.9694519154248875,
    "Field-weighted LSI": 0.966107888984751,
    "Field-weighted LSI with BERT-enhanced indexing": 0.9716148584744075
  },
  "overall_comparison": [
    {
      "system": "Field-weighted LSI with BERT-enhanced indexing",
      "average_ndcg@10": 0.9716148584744075
    },
    {
      "system": "Basic LSI with k=150 dimensions",
      "average_ndcg@10": 0.9694519154248875
    },
    {
      "system": "Field-weighted LSI",
      "average_ndcg@10": 0.966107888984751
    },
    {
      "system": "BM25 baseline",
      "average_ndcg@10": 0.9581363203901849
    }
  ]
}
"""

# Parse the JSON data
data = json.loads(data_json)

# Extract the query_ndcg values
query_ndcg = data["query_ndcg"]

# Initialize a dictionary to accumulate the per-system scores
system_scores = {}

for query, scores in query_ndcg.items():
    for system, ndcg in scores.items():
        system_scores.setdefault(system, []).append(ndcg)

# Compute the average, median, and standard deviation for each system
summary = []
for system, scores in system_scores.items():
    avg = np.mean(scores)
    median = np.median(scores)
    std = np.std(scores)
    summary.append({
        "System": system,
        "Average NDCG@10": avg,
        "Median NDCG@10": median,
        "STD NDCG@10": std
    })

# Create a DataFrame to display the summary
df_summary = pd.DataFrame(summary)
df_summary = df_summary.sort_values("Average NDCG@10", ascending=False).reset_index(drop=True)

print(df_summary)
# Out:
#                                            System  Average NDCG@10  \
# 0  Field-weighted LSI with BERT-enhanced indexing         0.971615
# 1                 Basic LSI with k=150 dimensions         0.969452
# 2                              Field-weighted LSI         0.966108
# 3                                   BM25 baseline         0.958136
#
#    Median NDCG@10  STD NDCG@10
# 0        0.980908     0.023714
# 1        0.972521     0.015790
# 2        0.976036     0.027842
# 3        0.965651     0.026032
